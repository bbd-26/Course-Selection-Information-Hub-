# %% [markdown]
# # 環境設定

# %% [markdown]
# ## 安裝 GPU 驅動相關套件

# %%
# 更新 Linux 內的套件清單至最新版
# !apt-get update

# 安裝 PCI 匯流排工具（PCI Utility）與 lshw (LiSt HardWare)，以便能偵測到 GPU
# -y：遇到詢問是否安裝，一律自動回答 yes
# !apt-get install -y pciutils lshw
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# lshw is already the newest version (02.19.git.2021.06.19.996aaad9c7-2build1).
# pciutils is already the newest version (1:3.7.0-6).
# 0 upgraded, 0 newly installed, 0 to remove and 54 not upgraded.

# %%
# 用 nVidia 的 System Management Interface (SMI) 確認 GPU 的確抓得到
# !nvidia-smi
# Out:
# Fri Dec 20 05:49:54 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## 安裝 Ollama

# %%
# 至 https://ollama.com/download/linux
# 直接將安裝 Ollama 於 Linux 的指令貼上
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# 啟動 Ollama，讓它執行於背景中
# ollama serve: 用 Server 模式、而非互動模式執行 Ollama
# > server.log：將本應顯示於螢幕的訊息，轉向輸出至 server.log 這個檔備查
# 2>&1：2 為 stderr。將所有錯誤訊息，轉向 &1 (stdout，螢幕) 輸出。
# &：將程式啟動之後，馬上返回，不要等該程式執行完成
# !ollama serve > server.log 2>&1 &

# %%
# 將 Llama-3 模型下載，並做為此次的大語言模型
# ollama run <模型名稱>：下載並執行特定 LLM
# > model.log：將本應顯示於螢幕的訊息，轉向輸出至 model.log 這個檔備查
# !ollama run gemma:7b > model.log 2>&1 &

# 注意：上述兩指令皆以「&」後綴，告知 Colab「不用等 Linux 執行完」。
# 但事實上，不論啟動為 Server，或下載 LLM，皆須 1~5 分鐘不等的時間。
# 可以查看 server.log、model.log 兩檔案內容，得知當前執行狀況。

# 將 nomic-embed-text 模型，拉下來備用
# nomic-embed-text 是一款能將文字向量化的嵌入層模型
# !ollama pull nomic-embed-text > embedding.log 2>&1 &

# %% [markdown]
# ## 安裝 LangChain + 連上大語言模型

# %%
# 下載 LangChain，一套專門連上各種大語言模型的 Python 套件
# !pip install langchain  # LangChain 核心元件
# !pip install langchain-community  # 各種開源大語言模型連接函數套件
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.10.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.28)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.7.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.13->langchain-community) (0.3.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.13->langchain-community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.13->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.13->langchain-community) (2.27.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.2.2)

# %%
# 載入 Ollama 以便連上後端 LLM
from langchain_community.llms import Ollama

# LLM 名稱需與 ollama run 後方名稱相同
llm = Ollama(model="gemma:7b")
# Out:
# <ipython-input-8-ee38639c5b59>:5: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="gemma:7b")

# %% [markdown]
# # RAG 環境設定及資料處理

# %% [markdown]
# ## 引入向量資料庫

# %%
# ChromaDB 是一款蠻受歡迎的開源式向量資料庫
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/dist-packages (0.5.23)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.10.3)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.29.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb) (0.27.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)

# %% [markdown]
# ## 匯入課程資訊相關文件文件

# %%
import os

# %%
# 此函數用於下載google drive上的檔案
def doc_download(Dataset_File,Data_url):
    """
    雲端檔案讀入
    """
    if not os.path.isfile(Dataset_File):
      url = url_trans(Data_url)
      os.system(f"wget {url} -O {Dataset_File}")

# %%
def url_trans(url):
    """
    將 Google Drive 網址轉換
    """
    if "https://drive.google.com/file/d/" in url:
        # 提取 ID 部分
        file_id = url.split("/file/d/")[1].split("/")[0]
        # 拼接成新的下載鏈接
        direct_url = f"https://drive.google.com/uc?id={file_id}"
        return direct_url
    else:
        raise ValueError("提供的網址格式不正確。請確認是 Google Drive 分享網址。")

# %%
doc_download("content.sorted.csv","https://drive.google.com/file/d/1_24DZraBJ4bJUpCV3bLGSCXtKptla_LQ/view?usp=drive_link")

# %% [markdown]
# ## 資料解析

# %%
#載入 CSV 資料
from langchain_community.document_loaders.csv_loader import CSVLoader


loader = CSVLoader(file_path='content.sorted.csv')
data = loader.load()

# %% [markdown]
# ### 若檔案非CSV檔時的處理流程

# %%
# # 安裝 JSON 檔內容解析套件
# !pip install jq
# from pathlib import Path  # 匯入 pathlib 模組
# import json  # 匯入 json 模組
# from langchain_community.document_loaders import JSONLoader

# %%
# #json檔解析
# def json_loader(file):
#   """
#     輸入檔案名稱解析檔案
#   """
#   file_path = Path(file)
#   with file_path.open(encoding="utf-8-sig") as f:
#       json_data = json.load(f)

#   return json_data

# %%
# file_path = Path("test.json")
# with file_path.open() as f:
#   json_data = json.load(f)

# print(json_data)

# %%
# !pip install pypdf

# %%
# # 載入 PDF 資料
# from langchain_community.document_loaders import PyPDFLoader

# loader = PyPDFLoader(test_pdf)
# test_doc = loader.load()

# print(test_doc)

# %%
# # 載入網頁資料
# from langchain_community.document_loaders import WebBaseLoader

# url = "https://goinglearn.com.tw/about-this-site"
# loader = WebBaseLoader(url)
# web_docs = loader.load()

# print(web_docs)

# %% [markdown]
# ## 資料合併

# %% [markdown]
# 此專案只用到一份檔案故資料合併非必要操作

# %%
all_docs = []

# %%
def add_file(file):
  global all_docs
  all_docs += file
  print(all_docs)

# %%
add_file(data)
# Out:
# [Document(metadata={'source': 'content.sorted.csv', 'row': 0}, page_content='course name: 民法總則\nsemester: 112-1\nteacher: 牛曰正\nreflection: 老師之後應該也不會在政大任教了（那就簡略寫寫），上課內容不難，主要是以講義所列課程大綱作說明、補充，課後要填回饋紙條蠻有趣的而且期末可以加分（事實上證明真的很需要😍）。期中是非常簡單的選擇題，期末就是殺人不眨眼的傢伙，選擇加每題都塞了爆多爭點的申論題，我也不知道我在寫啥但學期調分就是我的神。\nrating: 甜度：🍬🍬🍬🍬🍬 涼度：🧊🧊🧊🧊 分數：90-94 推薦指數：🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 1}, page_content='course name: 刑法（一）\nsemester: 112-1\nteacher: 謝如媛\nreflection: 非常喜歡如媛小淑女，上課節奏適中、教學內容扎實，考試內容不難（選擇題＋申論題），不過要注意的是學期成績是期中40分＋期末60分，分數扣起來很疼，如果像我一樣期末考爆就尷尬了。 另外要大大安利這門課的助教威齊，非常用心的編制講義與教學，在一開始進來法律系啥都不懂時真的都是透過威齊學習如何複習、如何做筆記、如何審題列架構，若還有不懂也可以寄信問他，他都會很有耐心很認真的把你教到會，是我非常仰慕且尊敬的助教大人。希望學弟妹有福氣遇到人家，遇到也要把人家好好拱著，這麼好的助教真的很難遇到喔！\nrating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 2}, page_content='course name: 刑法（二）\nsemester: 112-2\nteacher: 謝如媛\nreflection: 非常喜歡如媛小淑女，上課節奏適中、教學內容扎實，考試內容不難（選擇題＋申論題），不過要注意的是學期成績是期中40分＋期末60分，分數扣起來很疼，如果像我一樣期末考爆就尷尬了。 另外要大大安利這門課的助教威齊，非常用心的編制講義與教學，在一開始進來法律系啥都不懂時真的都是透過威齊學習如何複習、如何做筆記、如何審題列架構，若還有不懂也可以寄信問他，他都會很有耐心很認真的把你教到會，是我非常仰慕且尊敬的助教大人。希望學弟妹有福氣遇到人家，遇到也要把人家好好拱著，這麼好的助教真的很難遇到喔！\nrating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊 分數： 85-89  推薦指數：🍎🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 3}, page_content='course name: 民法債編總論（一）\nsemester: 112-2\nteacher: 呂彥彬\nreflection: 這門課的教學模式與之前上過的各種法律課程都很不一樣，授課主要是以案例教學，老師會帶著我們審題、架構、統整，期中期末都是上課學過的題型作變化，不過像是學說或各種理論就要自己跟著教科書學習。題外話，老師聲音莫名很有磁性很好聽，上課也常常分享他的朋友家庭日常跟稿又趕不完的煩惱，是個意外很風趣很不典型的法律教授，但我本人對債總一竅不通所以學得很痛苦，嗯嗯嗯。\nrating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 4}, page_content='course name: 法學的歷史、社會與思想\nsemester: 112-2\nteacher: 江玉林\nreflection: 上課教材為老師自編講義搭配上課時投放PPT（不會給同學，只能課程中拍照或作筆記），期中是從老師的上課講義找幾篇文章出來撰寫一份心得報告，期末考則是名詞解釋的簡答題與申論題（可開書，前一週有小提示）。老師本人是個詼諧幽默的人，很喜歡和台下的學生做互動，一開始我是抱著完蛋的心態來上這堂課，不過認真讀了幾次老師摘錄的文選以及老師本人的論文著作才發現基礎法學其實蠻有趣的，以後也會想再上他的課！不過這學期因為每堂實際到數的學生很少，老師有點難過（可能也反映在分數上）。\nrating: 甜度：🍬🍬 涼度：🧊🧊🧊 分數：80-85 推薦指數：🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 5}, page_content='course name: 政治學\nsemester: 112-1\nteacher: 蔡中民\nreflection: 年代久遠有點忘記了詳細的分數採計方式，不過印象中每堂課都有課前簽到／課後心得感想＋國際新聞，期中期末都是簡報中教過／老師口述／教科書（英文）的內容，只要有認真就不會太爛的。原本是看板上極多人推薦便選了，上完的確也很有收穫，尤其是老師對於各種理論學派都有獨到的見解，對於國際時事也有銳利的慧眼，很喜歡課前那一個小時與學生交流國際新聞的時間，總是收穫許多，身處老師的課堂但視野反而躍出擁擠狹隘的教室，讚！\nrating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 6}, page_content='course name: 憲法\nsemester: 112-2\nteacher: 劉定基\nreflection: 非常無敵爆炸喜歡定基的憲法課，是我收穫頗多成長頗大的一門課，相對其他科而言課程內容非常繁多且複雜，課前有預習簡報、各種釋字須提前預習（＋閱讀教科書），課中會不時抽問同學（不過似乎是照學號排，只會叫到一次），教材主要以老師授課簡報為主，內容非常詳實精細，架構連貫且精整，到期中才領略老師簡報的奧妙，期中期末都是選擇題申論題和時事題（如果我記錯再糾正我），我覺得選擇題的難度有比平時學的還輕許多，申論時事也像指引我們如何搭配釋字以闡述見聞。不過整體而言，相較其他班，定基的課肯定是非常痛苦難熬，不過若是對憲法有興趣或是純粹想把憲法學好，都非常推薦老師的課喔！ 另外推推這門課的助教巧妍學姊，不只人美心也善，編制的講義非常精實豐富，在講述各種也會章節時也會繪製架構圖、審查標準的分析促進我們吸收，期初也非常認真教對憲法一竅不通我們寫憲法的答題架構並附上範例，平時有練習也能傳給助教批改，非常用心，與老師的授課簡報亦相輔相成，能給巧妍教到也是非常有福氣要好好珍惜！\nrating: 甜度：🍬🍬🍬 涼度： 分數：90-94 推薦指數：🍎🍎🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 7}, page_content='course name: 民法總則實例研習\nsemester: 112-2\nteacher: 吳瑾瑜\nreflection: 有感於上學期似乎沒把民法學好，這學期便加選了瑾瑜老師的民總實例研習（實際上就是把老師上學期沒上完的課上完，這樣），最後也順利加簽到超開心。瑾瑜板書之精美，講義連貫各判決之一氣呵成，相信版上已有諸多討論，便不再贅述，選就對了，這學期直接變成瑾瑜的狂粉。宗憲助教人也超好，一開始因為覺得自己民總學習落拍許多非常忐忑，多虧助教的詳實的教學與不吝嗇的建議，讓我終算是步入正途，非常感謝！\nrating: 甜度：🍬🍬🍬 涼度：🧊 分數：95-99 推薦指數：🍎🍎🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 8}, page_content='course name: 生活中的數學、邏輯與運算思維（資訊通）\nsemester: 112-1\nteacher: 蔡炎龍\nreflection: 年代久遠大致都忘了，只記得上起來很輕鬆給分也很甜，不過我每週都有乖乖簽到上課、跟著練習，期中期末也有按時繳交，讚。\nrating: 甜度：🍬🍬🍬🍬🍬 涼度：🧊🧊🧊🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎\n: '), Document(metadata={'source': 'content.sorted.csv', 'row': 9}, page_content='course name: 近代臺灣歷史與人物（人文核通）\nsemester: 112-1\nteacher: 鄭麗榕\nreflection: 正課不太會點名但助教課都會，期中考前後有一次校外參訪（一定要到），期末考我記得老師助教們有偷偷提示出題範圍，當天也能帶資料入場，學期結束前也要繳交個人的小小說，也提供了加分作業的機會彌補一些失分，不過詳細的標準與計分方式可能要參考其他篇文章。補充！助教課常常會帶許多議題討論，布置的作業有幾項也蠻有趣的（像是畫自己的年代表，我到現在都好好珍藏著），也會和組員有許多互動，正課有時也會請課外的人來演講，很酷。\nratin ...

# %% [markdown]
# ## 資料切割

# %%
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# nomic-embed-text:latest    0a109f422b47    274 MB    21 seconds ago
# gemma:7b                   a72c7f4d0a15    5.0 GB    3 minutes ago

# %%
# !ollama start nomic-embed-text
# Out:
# Error: accepts 0 arg(s), received 1

# %%
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
import re

# 假設 all_docs 中的元素有些是字典，有些是 Document 類型的對象
all_docs_list = []
for doc in all_docs:
    if isinstance(doc, dict):  # 如果是字典，則轉換為 Document
        page_content = doc.get("reflection", "")  # 預設值為空字串
        metadata = {
            "課程名稱": doc.get("課程名稱", "未知課程"),
            "teacher": doc.get("teacher", "未知老師")  # 確保有提取teacher
        }  # 確保 metadata 是字典
        all_docs_list.append(Document(page_content=page_content, metadata=metadata))
    elif isinstance(doc, Document):  # 如果已經是 Document 類型，則直接使用
        page_content = doc.page_content

        # 使用正則表達式更新 metadata
        course_name_match = re.search(r'course name:\s*(.*?)\n', page_content)
        teacher_match = re.search(r'teacher:\s*(.*?)\n', page_content)

        # 如果找到了相應的匹配項，提取資料
        if course_name_match and teacher_match:
            course_name = course_name_match.group(1)
            teacher = teacher_match.group(1)

            # 更新原有 metadata
            doc.metadata.update({
                'course_name': course_name,
                'teacher': teacher
            })

        # 確保直接使用原始 Document 實例，無需重新創建
        all_docs_list.append(doc)
    else:
        raise ValueError(f"未知的資料格式：{type(doc)}")

# 初始化文本切分器
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

# 切分文檔
splits = text_splitter.split_documents(all_docs_list)

# 列印切分後的文檔
for split in splits:
    print(split)
# Out:
# page_content='course name: 民法總則
# semester: 112-1
# teacher: 牛曰正
# reflection: 老師之後應該也不會在政大任教了（那就簡略寫寫），上課內容不難，主要是以講義所列課程大綱作說明、補充，課後要填回饋紙條蠻有趣的而且期末可以加分（事實上證明真的很需要😍）。期中是非常簡單的選擇題，期末就是殺人不眨眼的傢伙，選擇加每題都塞了爆多爭點的申論題，我也不知道我在寫啥但學期調分就是我的神。
# rating: 甜度：🍬🍬🍬🍬🍬 涼度：🧊🧊🧊🧊 分數：90-94 推薦指數：🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 0, 'course_name': '民法總則', 'teacher': '牛曰正'}
# page_content='course name: 刑法（一）
# semester: 112-1
# teacher: 謝如媛
# reflection: 非常喜歡如媛小淑女，上課節奏適中、教學內容扎實，考試內容不難（選擇題＋申論題），不過要注意的是學期成績是期中40分＋期末60分，分數扣起來很疼，如果像我一樣期末考爆就尷尬了。 另外要大大安利這門課的助教威齊，非常用心的編制講義與教學，在一開始進來法律系啥都不懂時真的都是透過威齊學習如何複習、如何做筆記、如何審題列架構，若還有不懂也可以寄信問他，他都會很有耐心很認真的把你教到會，是我非常仰慕且尊敬的助教大人。希望學弟妹有福氣遇到人家，遇到也要把人家好好拱著，這麼好的助教真的很難遇到喔！
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 1, 'course_name': '刑法（一）', 'teacher': '謝如媛'}
# page_content='course name: 刑法（二）
# semester: 112-2
# teacher: 謝如媛
# reflection: 非常喜歡如媛小淑女，上課節奏適中、教學內容扎實，考試內容不難（選擇題＋申論題），不過要注意的是學期成績是期中40分＋期末60分，分數扣起來很疼，如果像我一樣期末考爆就尷尬了。 另外要大大安利這門課的助教威齊，非常用心的編制講義與教學，在一開始進來法律系啥都不懂時真的都是透過威齊學習如何複習、如何做筆記、如何審題列架構，若還有不懂也可以寄信問他，他都會很有耐心很認真的把你教到會，是我非常仰慕且尊敬的助教大人。希望學弟妹有福氣遇到人家，遇到也要把人家好好拱著，這麼好的助教真的很難遇到喔！
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊 分數： 85-89  推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 2, 'course_name': '刑法（二）', 'teacher': '謝如媛'}
# page_content='course name: 民法債編總論（一）
# semester: 112-2
# teacher: 呂彥彬
# reflection: 這門課的教學模式與之前上過的各種法律課程都很不一樣，授課主要是以案例教學，老師會帶著我們審題、架構、統整，期中期末都是上課學過的題型作變化，不過像是學說或各種理論就要自己跟著教科書學習。題外話，老師聲音莫名很有磁性很好聽，上課也常常分享他的朋友家庭日常跟稿又趕不完的煩惱，是個意外很風趣很不典型的法律教授，但我本人對債總一竅不通所以學得很痛苦，嗯嗯嗯。
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 3, 'course_name': '民法債編總論（一）', 'teacher': '呂彥彬'}
# page_content='course name: 法學的歷史、社會與思想
# semester: 112-2
# teacher: 江玉林
# reflection: 上課教材為老師自編講義搭配上課時投放PPT（不會給同學，只能課程中拍照或作筆記），期中是從老師的上課講義找幾篇文章出來撰寫一份心得報告，期末考則是名詞解釋的簡答題與申論題（可開書，前一週有小提示）。老師本人是個詼諧幽默的人，很喜歡和台下的學生做互動，一開始我是抱著完蛋的心態來上這堂課，不過認真讀了幾次老師摘錄的文選以及老師本人的論文著作才發現基礎法學其實蠻有趣的，以後也會想再上他的課！不過這學期因為每堂實際到數的學生很少，老師有點難過（可能也反映在分數上）。
# rating: 甜度：🍬🍬 涼度：🧊🧊🧊 分數：80-85 推薦指數：🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 4, 'course_name': '法學的歷史、社會與思想', 'teacher': '江玉林'}
# page_content='course name: 政治學
# semester: 112-1
# teacher: 蔡中民
# reflection: 年代久遠有點忘記了詳細的分數採計方式，不過印象中每堂課都有課前簽到／課後心得感想＋國際新聞，期中期末都是簡報中教過／老師口述／教科書（英文）的內容，只要有認真就不會太爛的。原本是看板上極多人推薦便選了，上完的確也很有收穫，尤其是老師對於各種理論學派都有獨到的見解，對於國際時事也有銳利的慧眼，很喜歡課前那一個小時與學生交流國際新聞的時間，總是收穫許多，身處老師的課堂但視野反而躍出擁擠狹隘的教室，讚！
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 5, 'course_name': '政治學', 'teacher': '蔡中民'}
# page_content='course name: 憲法
# semester: 112-2
# teacher: 劉定基
# reflection: 非常無敵爆炸喜歡定基的憲法課，是我收穫頗多成長頗大的一門課，相對其他科而言課程內容非常繁多且複雜，課前有預習簡報、各種釋字須提前預習（＋閱讀教科書），課中會不時抽問同學（不過似乎是照學號排，只會叫到一次），教材主要以老師授課簡報為主，內容非常詳實精細，架構連貫且精整，到期中才領略老師簡報的奧妙，期中期末都是選擇題申論題和時事題（如果我記錯再糾正我），我覺得選擇題的難度有比平時學的還輕許多，申論時事也像指引我們如何搭配釋字以闡述見聞。不過整體而言，相較其他班，定基的課肯定是非常痛苦難熬，不過若是對憲法有興趣或是純粹想把憲法學好，都非常推薦老師的課喔！ 另外推推這門課的助教巧妍學姊，不只人美心也善，編制的講義非常精實豐富，在講述各種也會章節時也會繪製架構圖、審查標準的分析促進我們吸收，期初也非常認真教對憲法一竅不通我們寫憲法的答題架構並附上範例，平時有練習也能傳給助教批改，非常用心，與老師的授課簡報亦相輔相成，能給巧妍教到也是非常有福氣要好好珍惜！
# rating: 甜度：🍬🍬🍬 涼度： 分數：90-94 推薦指數：🍎🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 6, 'course_name': '憲法', 'teacher': '劉定基'}
# page_content='course name: 民法總則實例研習
# semester: 112-2
# teacher: 吳瑾瑜
# reflection: 有感於上學期似乎沒把民法學好，這學期便加選了瑾瑜老師的民總實例研習（實際上就是把老師上學期沒上完的課上完，這樣），最後也順利加簽到超開心。瑾瑜板書之精美，講義連貫各判決之一氣呵成，相信版上已有諸多討論，便不再贅述，選就對了，這學期直接變成瑾瑜的狂粉。宗憲助教人也超好，一開始因為覺得自己民總學習落拍許多非常忐忑，多虧助教的詳實的教學與不吝嗇的建議，讓我終算是步入正途，非常感謝！
# rating: 甜度：🍬🍬🍬 涼度：🧊 分數：95-99 推薦指數：🍎🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 7, 'course_name': '民法總則實例研習', 'teacher': '吳瑾瑜'}
# page_content='course name: 生活中的數學、邏輯與運算思維（資訊通）
# semester: 112-1
# teacher: 蔡炎龍
# reflection: 年代久遠大致都忘了，只記得上起來很輕鬆給分也很甜，不過我每週都有乖乖簽到上課、跟著練習，期中期末也有按時繳交，讚。
# rating: 甜度：🍬🍬🍬🍬🍬 涼度：🧊🧊🧊🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 8, 'course_name': '生活中的數學、邏輯與運算思維（資訊通）', 'teacher': '蔡炎龍'}
# page_content='course name: 近代臺灣歷史與人物（人文核通）
# semester: 112-1
# teacher: 鄭麗榕
# reflection: 正課不太會點名但助教課都會，期中考前後有一次校外參訪（一定要到），期末考我記得老師助教們有偷偷提示出題範圍，當天也能帶資料入場，學期結束前也要繳交個人的小小說，也提供了加分作業的機會彌補一些失分，不過詳細的標準與計分方式可能要參考其他篇文章。補充！助教課常常會帶許多議題討論，布置的作業有幾項也蠻有趣的（像是畫自己的年代表，我到現在都好好珍藏著），也會和組員有許多互動，正課有時也會請課外的人來演講，很酷。
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 9, 'course_name': '近代臺灣歷史與人物（人文核通）', 'teacher': '鄭麗榕'}
# page_content='course name: 轉型期與近代東亞：從1930年代到1940年代（人文通）
# semester: 112-1
# teacher: 曾士榮
# reflection: 我覺得我沒有很適應上課速度，但如果只是想要涼涼的修課可以選，只有期中報告進度跟大綱然後期末完成團體報告，跟平時偶爾點名這樣。
# rating: 甜度：🍬🍬🍬 涼度：🧊🧊🧊🧊🧊 分數：90-94 推薦指數：🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 10, 'course_name': '轉型期與近代東亞：從1930年代到1940年代（人文通）', 'teacher': '曾士榮'}
# page_content='course name: 國文---中國思想名作選讀
# semester: 112-1
# teacher: 林啓屏
# reflection: 上課主要是以老師編制的講義作教學，雖然上課內容有點深奧（哲學），常常上完一整堂課還懵懵懂懂，不過看著老師滔滔地講述著各種學派的理論以及分析各式思想時都能感受到老師的博學多聞，當真體會到何為「偉岸」男子是也，還是很推薦大家來感受老師帶來的震撼（一上修的時候有被大學的博廣嚇到，會發現自己也太貧瘠，自慚形穢）。印象中有加分作文，期末有個人小論文、團體報告跟期末考，團體報告主要是要跟思想有關即可（慎選組員比較重要），期末考就是針對教授口述＋講義做準備，不過裡面也有關於期中老師給我們看的真愛伴我行的分析，十八週似乎還要繳交一份有關故鄉名勝的作業。
# rating: 甜度：🍬🍬 涼度：🧊🧊 分數：90-94 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 11, 'course_name': '國文---中國思想名作選讀', 'teacher': '林啓屏'}
# page_content='course name: 大學英文（一）
# semester: 112-1
# teacher: 郭曉蓉
# reflection: 曉蓉的課偏主題式教學，每門課都有不同的主題，搭配各種小活動與團體討論，透過各種方式增益口說與閱讀能力，對英文非常爛的我來說相當友善，雖然被點到回答時都很ㄘㄨㄚˋ，但老師都不會催我或否定，給了我超多鼓勵跟肯定的，非常感謝。有期中期末考、期末團體報告，每學期也有一次個人報告，我覺得都不會有很多壓力，就盡量嘗試盡量努力，會拿到滿意的分數的！
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 12, 'course_name': '大學英文（一）', 'teacher': '郭曉蓉'}
# page_content='course name: 大學英文（二）
# semester: 112-2
# teacher: 郭曉蓉
# reflection: 曉蓉的課偏主題式教學，每門課都有不同的主題，搭配各種小活動與團體討論，透過各種方式增益口說與閱讀能力，對英文非常爛的我來說相當友善，雖然被點到回答時都很ㄘㄨㄚˋ，但老師都不會催我或否定，給了我超多鼓勵跟肯定的，非常感謝。有期中期末考、期末團體報告，每學期也有一次個人報告，我覺得都不會有很多壓力，就盡量嘗試盡量努力，會拿到滿意的分數的！
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 13, 'course_name': '大學英文（二）', 'teacher': '郭曉蓉'}
# page_content='course name: 教育探索與自我學習（社會通）
# semester: 112-2
# teacher: 李淑菁
# reflection: 如果你也對濕黏悶熱的文山區、煩悶沉重的必修課和冷漠痛苦的異鄉生活感到痛苦的話，歡迎選修這門課，脫離制式的教育框架，以「旅行」為題，你可以學習如何自主冥想、靜心；你可以透過課間活動去開闊政大尚未走過的蜿蜒山路、沐浴午後太陽的操場；你可以透過作業主動走出政大走出指南路走出文山，去從未到過的咖啡廳、市場、台北的不知名角落晃晃；你可以從老師的見聞心得分享學習如何安排獨旅、享受獨旅；你可以稍微解開被功名課業綁住的自己去感受生命；最重要的是你可以在短短的三個小時內學習把一個沉重的二十歲的自己接住。 這是一堂非常溫暖而療癒的課程，希望能感受到我的喜歡！
# rating: 甜度：🍬🍬🍬🍬🍬 涼度：🧊🧊🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 14, 'course_name': '教育探索與自我學習（社會通）', 'teacher': '李淑菁'}
# page_content='course name: 醫療與生活（自然通）
# semester: 112-2
# teacher: 呂志得
# reflection: 課程相對輕鬆許多，也常常有其他班的老師或學者輪替上課，如果有認真上課應該蠻有趣的，期中繳交一篇跟醫療相關的電影或書籍等的閱讀心得，期末則是關於癌症的團體報告，沒有甚麼壓力，對考試太多的人來說是個福音。
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊🧊🧊 分數：90-94 推薦指數：🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 15, 'course_name': '醫療與生活（自然通）', 'teacher': '呂志得'}
# page_content='course name: 體育[男女合班]---羽球初級
# semester: 112-2
# teacher: 黃郁琦
# reflection: 老師是個人很好的阿伯，平常上課很常巡堂指導、修正學生的動作，學期就是看簽到跟期中期末測驗分數堆加，期中期末有一定的難度（對我來說），但如果平時有乖乖地照著老師的進度學習，期中期末考應該都能順利通過，雖然一開始都有限考試次數，但學期末最後一堂課有給我們補考機會，如果對分數不滿意都可以排隊重測（感覺後期很盡力在送分給我們）。 不過期末真的緊張到腦袋空白到我覺得我進入了zone模式，阿彌陀佛。
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊🧊🧊 分數：95-99 推薦指數：🍎🍎🍎🍎🍎
# :' metadata={'source': 'content.sorted.csv', 'row': 16, 'course_name': '體育[男女合班]---羽球初級', 'teacher': '黃郁琦'}
# page_content='course name: 總體經濟學
# semester: N/A
# teacher: 洪福聲
# reflection: 師講解的非常清楚，有跟著上課的步調考試蠻輕鬆的，上課有錄影片沒來可以自己看，助教課的話會帶題目幫助理解觀念，上完這堂課很喜歡總經，非常推薦
# rating: 甜：🍭🍭🍭🍭🍭 涼：🧊🧊🧊🧊 分數：95-100
# :' metadata={'source': 'content.sorted.csv', 'row': 17, 'course_name': '總體經濟學', 'teacher': '洪福聲'}
# page_content='course name: 總體經濟學
# semester: N/A
# teacher: 莊奕琦
# reflection: 老師感覺比較偏學術研究型，上課也會講蠻多時事的部分，而且上課發言可以加總分，考試內容有去上助教課的會就沒什麼問題
# rating: 甜：🍭🍭🍭🍭 涼：🧊🧊🧊 分數：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 18, 'course_name': '總體經濟學', 'teacher': '莊奕琦'}
# page_content='course name: 個體經濟學
# semester: N/A
# teacher: 陳鎮洲
# reflection: 這堂課要考三次試還有分組作業，個人認為有一點點負擔，老師講解也算是很清楚，跟著上助教課考試會輕鬆很多，考試通常跟考古題沒什麼差
# rating: 甜：🍭🍭🍭🍭 涼：🧊🧊🧊 分數：95-100
# :' metadata={'source': 'content.sorted.csv', 'row': 19, 'course_name': '個體經濟學', 'teacher': '陳鎮洲'}
# page_content='course name: 商事法
# semester: N/A
# teacher: 劉承愚
# reflection: 上這堂課壓力有點大，要課前預習，但老師上課很精彩，會講到很多實務的東西，蠻有趣的。考試單選複選混在一起（就是你不知道這題是單選還是複選），但我也不知道我考試到底考幾分，分數有點玄
# rating: 甜：🍭🍭🍭🍭🍭 涼：🧊🧊 分數：95-100
# :' metadata={'source': 'content.sorted.csv', 'row': 20, 'course_name': '商事法', 'teacher': '劉承愚'}
# page_content='course name: 初級韓國語
# semester: N/A
# teacher: 高胤茹
# reflection: 很推推爆快來選，老師超漂亮🥹上課內容都會講到韓國文化跟時事，上課很有趣不會想睡覺，願意練習對話的話還可以加總分，但考試可能就要花時間讀一下，對初學者可能有點難
# rating: 甜：🍭🍭🍭🍭🍭 涼：🧊🧊🧊🧊 分數：95-100
# :' metadata={'source': 'content.sorted.csv', 'row': 21, 'course_name': '初級韓國語', 'teacher': '高胤茹'}
# page_content='course name: 中級會計學
# semester: N/A
# teacher: 金成隆
# reflection: 個人覺得沒有板上講的那麼糟，願意認真聽還是可以學到一點東西，但其實上助教課就差不多了，考試內容都是跟批批踢差不多的東西，但要考三次蠻累的…
# rating: 甜：🍭🍭🍭🍭 涼：🧊🧊🧊 分數：85-90
# :' metadata={'source': 'content.sorted.csv', 'row': 22, 'course_name': '中級會計學', 'teacher': '金成隆'}
# page_content='course name: 財務管理
# semester: N/A
# teacher: 盧敬植
# reflection: 可能沒天份覺得蠻難的，上課內容感覺不太夠考試用，要自己讀課本，但老師在講解觀念蠻仔細的，考試一部分手寫跟作業還很像，但作業要自己花錢買軟體，很窮的人不要選，成績完全看你考幾分，不調分
# rating: 甜：🍭🍭 涼：🧊🧊 分數：80-85
# :' metadata={'source': 'content.sorted.csv', 'row': 23, 'course_name': '財務管理', 'teacher': '盧敬植'}
# page_content='course name: ［資訊通］生活中的數學、邏輯與運算思維
# semester:
# teacher:
# reflection: 老師從很基礎開始教，可以學到東西也不會太艱澀聽不懂，作業也蠻簡單的，期中末各一個專案，但給分好像有點玄，如果論上課內容蠻推薦的
# rating: 甜：🍭🍭🍭🍭🍭 涼：🧊🧊🧊🧊 分數：95-100
# :' metadata={'source': 'content.sorted.csv', 'row': 24, 'course_name': '［資訊通］生活中的數學、邏輯與運算思維', 'teacher': 'reflection: 老師從很基礎開始教，可以學到東西也不會太艱澀聽不懂，作業也蠻簡單的，期中末各一個專案，但給分好像有點玄，如果論上課內容蠻推薦的'}
# page_content='course name: ［核通］教育探索與自我學習
# semester:
# teacher: 王素芸
# reflection: 不太知道這堂課在幹嘛，可能我對教育沒什麼興趣，作業跟報告雜七雜八的事有點多，每堂課點名，建議對教育有興趣的人修 積功德 祝大家選課順利
# rating: 甜：🍭🍭🍭 涼：🧊🧊 分數：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 25, 'course_name': '［核通］教育探索與自我學習', 'teacher': '王素芸'}
# page_content='course name: 民事訴訟法（一）（二）
# semester: 112-1、112-2
# teacher: 劉明生
# reflection: 本人是乖乖上課派，每堂課都有去，我覺得這樣比較容易理解阿生哥老師的教科書（上課一定會用到書，特別是有些老師自創的表格/圖需要聽課才看得懂其中奧義），而且有時候老師會跳來跳去講不同章節的內容，沒去上課很可能會漏掉。期中考印象中都是選擇題（不能帶法條），期末是單純實例題（可帶法條）或實例＋選擇（不能帶法條），老師要考試之前會問同學想要考哪種題型。老師很可愛，而且是美食家，大家可以多多關注老師的粉絲團。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 26, 'course_name': '民事訴訟法（一）（二）', 'teacher': '劉明生'}
# page_content='course name: 刑事訴訟法（一）
# semester: 112-1
# teacher: 何賴傑
# reflection: 老師講課很生動，不時穿插笑點，上課舉過的例子考試可能會考（真的很重要）。考試都是選擇題（可帶法條），但題目多半需要思考或多拐幾個彎才能得到答案，建議還是要讀熟再去考試。附帶一提，個人覺得老師很帥而且穿搭很有型。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 27, 'course_name': '刑事訴訟法（一）', 'teacher': '何賴傑'}
# page_content='course name: 家事法實例研習
# semester: 112-1
# teacher: 戴瑀如
# reflection: 前半學期著重於繼承編，跟身分法最大的不同在於這堂課需要做小組報告，並需上台分享。我覺得收穫還蠻大的，而且可以順便跟同學增進感情。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 28, 'course_name': '家事法實例研習', 'teacher': '戴瑀如'}
# page_content='course name: 商事法總論與公司法＋公司法案例研習（二）
# semester: 112-1
# teacher: 周振鋒
# reflection: 每週五上四個小時真的是要我命。不過老師常常安排專家學者在第四節講座，有稍微緩解不自覺靈魂出竅的狀況（對不擠我就是顆草莓）。考試可以帶大抄，這時候可以見識到大家word功力如何。建議考試前一週開始吃葉黃素，我當初沒吃，考完出來體感近視增加50度。曾經考慮要問老師可否帶放大鏡進考場。（當然如果你有讀熟才去考試、不用一直看大抄就不會遇到這種狀況）
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 29, 'course_name': '商事法總論與公司法＋公司法案例研習（二）', 'teacher': '周振鋒'}
# page_content='course name: 財產法實例研習
# semester: 112-1
# teacher: 張韻琪
# reflection: 我大二時也是上老師的債各，本學期基本上就是把大二債各剩下的條文講完，有時候會指定閱讀文獻或判決書，上課時討論&講解，如果沒有人主動就會點人分享（如果跟老師眼神交會到的高機率會被點哈哈）。老師很讚很可愛（詳情請見111年的心得），考試不算難（老師好像喜歡出「假設你是其中一方律師」類型的題目）。總體而言，考試範圍相較之前債總債各比較小，有選擇＋實例題。不能自己帶法條，但考實例題時會發下空白法條給同學參考。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 30, 'course_name': '財產法實例研習', 'teacher': '張韻琪'}
# page_content='course name: 證券交易法
# semester: 112-2
# teacher: 林國全
# reflection: 老師準備的講義很完整且詳細（老師自己的見解也會特別標示出來），而且上課會非常仔細地講解。每堂課都會點人唸法條（開學時好像有說如果都有到的話，如果期末考成績不理想，可能會把你救回來，若此資訊有誤歡迎指正）。老師講課還蠻幽默的，也常常會分享一些立法背景等小故事，大大緩解證交法的枯燥、繁瑣。期末考開書考，基本上什麼都可以帶（平板也可以），但題目不少且多數非直覺型題目，建議還是要對內容有印象再來應考，不然你還是會不知道要翻哪裡。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 31, 'course_name': '證券交易法', 'teacher': '林國全'}
# page_content='course name: 保險法
# semester: 112-2
# teacher: 葉啟洲
# reflection: 啟洲的課應該不用特別推薦了，大家都會選吧哈哈哈。但面對考試成績還是要心臟大顆一點，努力寫拼命寫。這次也是因為期中考成績不盡理想，老師有把期末考調成超過100分。btw老師的上課簡報好漂亮
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 32, 'course_name': '保險法', 'teacher': '葉啟洲'}
# page_content='course name: 海商法
# semester: 112-2
# teacher: 張新平
# reflection: 大推海商法！個人覺得這堂課屬於有讀有分，考試內容在課本＆簡報都找得到，而且海商法的內容蠻有趣的，老師的簡報助益很大，建議大家考試前熟讀再熟讀。尤其是期中考申論題的部分，基本上只要把課本上提到的學說實務爭議霹哩啪拉寫上去，分數就會很漂亮！名詞解釋則可以在簡報上找到答案～考前記得背一背。如果真的心有餘而力不足，建議在期中考範圍比較小的時候，先一次衝高成績，就算期末考實例題滑坡應該也不至於太慘（？）期末考準備實例題的時候，我有把老師簡報抓的考古題都大致寫過一遍（其實還挺多的），因為期中考考得不錯，所以一股勁上來想要證明自己不是半途而廢的人哈哈哈。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 33, 'course_name': '海商法', 'teacher': '張新平'}
# page_content='course name: 衝突管理與調解學
# semester: 112-2
# teacher: 姜世明
# reflection: 如果對調解法/調解實務有興趣的很適合來這堂課組隊做期末報告！基本上形式不拘，但盡可能貼近調解實務現場，並運用老師上課＆書籍中提及的技巧，各組需要寫劇本＋現場演示給全班看。我覺得有好組員很重要，但如果找不到也可以選擇去考申論題，或自己寫個劇本交給老師也可以，只是印象中有參與現場演示的分數會比較高。不過我自己覺得這堂課最大的收穫就是在組隊寫劇本的時候，不然很多上課提過的理論可能聽過就忘了/根本不理解，實際要演出來的時候，才會發現原來有很多小細節要注意（eg調解人要表達理解當事人情緒，同時又不偏袒任何一方，因此用語都需要特別斟酌）這堂課比較可惜的是沒有示範影帶可以觀摩，但如果有修仲裁法，或本來就對諮商理論有背景知識的同學，可以選下去應該不會後悔。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 34, 'course_name': '衝突管理與調解學', 'teacher': '姜世明'}
# page_content='course name: 仲裁法
# semester: 112-2
# teacher: 李家慶
# reflection: 大推仲裁法！建議大家可以像我一樣同時選「衝突管理與調解學」一起服用，效果更佳。這堂課首先會先帶大家進一步區分ADR下的種類及適用，接著深入了解仲裁的學說實務爭議，老師本身的經驗談（曾經手的仲裁案件）也讓課程內容更具體而不流於空泛。考前老師會先提示幾個題目（申論題＋部分名詞解釋），申論題可以先去查閱學者文章做準備（我整個越看越起勁><），老師也會提示作答方向，未公佈的部分名詞解釋，就看對簡報內容熟不熟悉了。不過這堂課應該不算甜課。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 35, 'course_name': '仲裁法', 'teacher': '李家慶'}
# page_content='course name: 諮商理論與技術
# semester: 112-1
# teacher: 郭俊豪
# reflection: 是一堂沒有什麼壓力的課，每週去上課都當成在淨化我越來越世俗的心靈XD平時會留時間給個小組做演練，時間地點不限，只要你寫得出來心得紀錄就好。不過如果是希望對諮商理論有更深刻的了解，可參閱我在111年的選課心得，裡面有更適合的課程。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 36, 'course_name': '諮商理論與技術', 'teacher': '郭俊豪'}
# page_content='course name: 初級德文聽力會話
# semester: 112-1
# teacher: 蔡莫妮
# reflection: 大一的時候有修過查老師的德語暑期班，後來就一路荒廢至今。上學期不知道哪根筋不對決定重拾這一科，但有鑒於專業課程實在進度太快，個人外務又一堆，因此下學期就果斷斷捨離，以免被成績壓在地上打。基本上期中考的內容都可以臨時抱佛腳，而期末考可能需要早一點點準備比較不會緊張。（雖然我還是拖到最後一刻><）但我覺得如果你本身就是歐語系學生應該不用擔心，因為我是完全沒有修其他德語組必修的狀況下才有這種困擾。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 37, 'course_name': '初級德文聽力會話', 'teacher': '蔡莫妮'}
# page_content='course name: 民法債編總論（一）
# semester: N/A
# teacher: 向明恩
# reflection: 這是一堂一定要認真上的課，就算上課沒有太認真助教課也一定要認真！！這學期的助教都很臥龍藏虎，除了說清楚上課觀念之外更多的是教解題，解題也會分享自己的獨門步驟，而且分數大調分（不過期中是真的慘，改得偏嚴）。缺點是前期老師上太慢導致後期趕火車會跟的有些吃力。成績的話是看兩次考試（期中期末），不過不用擔心老師會調分，如果有讓老師感受到自己的努力（例如找她討論題目等等）據說會調的比較多。期中期末皆是申論題，可帶未註記法典需要做充足的準備才比較好應付！
# rating: 甜度：3／5 涼度：2／5 分數：81-85
# :' metadata={'source': 'content.sorted.csv', 'row': 38, 'course_name': '民法債編總論（一）', 'teacher': '向明恩'}
# page_content='course name: 刑法（二）
# semester: N/A
# teacher: 謝如媛
# reflection: 老師上課大部分都是用ppt也會上傳到moodle，因此複習預習都十分方便。助教課以講解觀念為主，會帶題目但不是很多。成績是看期中期末以及出席，出席是老師上課會點人念東西，沒找到人就算缺席。期中期末皆是選擇+申論的形式。一樣算是一分耕耘一分收穫的課程這樣～
# rating: 甜度：3／5 涼度：2／5 分數：71-75
# :' metadata={'source': 'content.sorted.csv', 'row': 39, 'course_name': '刑法（二）', 'teacher': '謝如媛'}
# page_content='course name: 憲法
# semester: N/A
# teacher: 林佳和
# reflection: 老師上課也是以ppt為主但會摻雜很藝術的板書，上課喜歡時不時蹦出德文。算是需要對到電波會覺得收穫滿滿的老師（但我對不到）。成績只看期末考試從不點名，上課超涼，但期末考的考法是沒什麼掙扎餘地的因為簡答題會就是會不會就是不會。不過老師說過不當人（除非真的很誇張考卷一半不作答或連基礎觀念都沒有的那種），算是下限高但是想拿更高成績還是得努力的課程。
# rating: 甜度：3／5 涼度：5／5 分數：71-75
# :' metadata={'source': 'content.sorted.csv', 'row': 40, 'course_name': '憲法', 'teacher': '林佳和'}
# page_content='course name: 法學的歷史社會與思想
# semester: N/A
# teacher: 黃士軒
# reflection: 老師上課都用自己的講義，但是講解時候會用自己的方式捋一遍也會補充一些東西，真的講解得非常清楚有趣，可能因為這堂課的性質有種在上歷史課的感覺，但士軒真的講得超好推推！！整學期不定時用小紙條點名三次全勤期末考試會加分，偶爾抽人登記，成績也是看期末考試，考試全選擇題印象中25題而已，因此一不小心也會再見，比較注意的是老師是日派因此一些容易搞錯的人名可能要注意，上課基本上有聽故事的感覺算蠻涼的。
# rating: 甜度：4／5 涼度：4／5 成績：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 41, 'course_name': '法學的歷史社會與思想', 'teacher': '黃士軒'}
# page_content='course name: 大學英文（二）
# semester: N/A
# teacher: 郭曉蓉
# reflection: 上課大部分的時間都在做活動跟報告，口語部分是有占一定比中的。但是相對而言成績算法算平均包含個人報告、小組報告和期中期末兩次考試，甚至有開放加分題。點名我不大確定因為老師曾經說過她有把大家記起來。認真準備可以拿到不錯的成績單但是確實是要做大約3次左右報告。期中考寫作期末考口說但評分我覺得算寬鬆（？），順帶一提分組可以延用上學期也可以自己再分老師有說過都可以。
# rating: 甜度：4／5 涼度：3／5 成績：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 42, 'course_name': '大學英文（二）', 'teacher': '郭曉蓉'}
# page_content='course name: 藝術與當代社會
# semester: N/A
# teacher: 郭力昕
# reflection: 這是一門我覺得很有趣的通識課！除了一般的上課之外老師也會請人（像是導演、藝術創作者等，這次甚至請到奧地利的電玩團隊）來分享解釋理念，對於拓展自己的所見所聞蠻有幫助的。一般上課的時候偶爾會有問答環節可以加分，但我大部分時間都在摸魚其實滿涼的。評分方式是用三次作業、展覽心得以及期末考、助教課來評分。基本上作業認真寫都有85以上，但我覺得比較需要注意的是期末考看影片寫心得影片是全英文的，甚至沒有中文字幕，英文能力可能需要評估一下。
# rating: 甜度：4／5 涼度：5／5 分數：96-100
# :' metadata={'source': 'content.sorted.csv', 'row': 43, 'course_name': '藝術與當代社會', 'teacher': '郭力昕'}
# page_content='course name: 選修英文：閱讀與口語訓練（ETP專班）
# semester: N/A
# teacher: 陳綉瑜
# reflection: 這是一堂口語能力需要基礎的課程，但其實老師判定蠻寬鬆的，甚至可以帶稿上台報告。不過上課會幾乎是用全英文對談討論哦。這堂課評分方式就是報告（作業、考試也都是報告），整學期小組個人報告加起來大約6次上下。但是我自己感覺老師比起用字高不高級更在意能不能完整傳遞想法，所以也不用太有壓力（？），就是大方分享自己的所見所聞基本上分數不會太低！
# rating: 甜度：4／5 涼度：5／5 分數：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 44, 'course_name': '選修英文：閱讀與口語訓練（ETP專班）', 'teacher': '陳綉瑜'}
# page_content='course name: 武術初級
# semester: N/A
# teacher: 張仲豪
# reflection: 是一門偏扎實的體育課程，但是分數甜到讓我覺得值得。上課可以多跟老師互動他其實蠻有趣的，主要學的是詠春，分數是看三次心得以及出缺席。但是是真的滿累我上完都會去吃東西跟小睡一下。順便說個中級武術會帶拳套實際演練，感覺挺好玩的！
# rating: 甜度：5／5 涼度：2／5 分數：96-100
# :' metadata={'source': 'content.sorted.csv', 'row': 45, 'course_name': '武術初級', 'teacher': '張仲豪'}
# page_content='course name: 經濟學
# semester: 112-1/112-2
# teacher: 黃台心
# reflection: 老師上課就是照著簡報念，放在moodle上的簡報跟實際上課的不太一樣，但足夠應付不買書單看簡報就考試的人。一學期有五次作業，無小考。期中考偏難，期末大會考只給三年的考古題（建議找修吳文傑課的同學拿10年考古）。不定期點名，一學期可能點2～3次，點名只是加分用的，點到一次加總成績3分的樣子。
# rating: 成績86/83 涼度：9/10 甜度：5/10
# :' metadata={'source': 'content.sorted.csv', 'row': 46, 'course_name': '經濟學', 'teacher': '黃台心'}
# page_content='course name: 初級會計學（一）（二）
# semester: 112-1/112-2
# teacher: 潘健民
# reflection: 老師不點名也沒有小考，期中期末前都各有一次作業，但非常簡單，有交就滿分。兩次期中都蠻簡單的（相比大會考），Kevin潘堪稱初會佛一般的存在，真的甜又涼。不過如果想把會計學的非常紮實的可能要修別堂，潘老師的會計比較輕鬆但不會非常深入（比如說做超長的報表）。分數配比是最高分50%、次高30%、最低20%，意思就是若前兩次考的不錯，期末殺爆全校的大會考爆了也沒關係，只佔20%喔（佛心變相調分）。老師人真的很好👍
# rating: 成績80/80 涼度10/10 甜度8/10
# :' metadata={'source': 'content.sorted.csv', 'row': 47, 'course_name': '初級會計學（一）（二）', 'teacher': '潘健民'}
# page_content='course name: 統計學（一）
# semester: 112-1
# teacher: 陳立榜
# reflection: 榜哥上課非常紮實，可以學到很深的統計學，上課不點名但強烈建議每堂課要到，不然會跟不上。沒有作業，一學期小考兩次（各10%），期中30%、期末50%。期末整學期範圍，佔比重而且不簡單，但考試可以帶一張公式紙，所以想學好統計找榜哥準沒錯👌🏻
# rating: 成績94 涼度8/10 甜度4/10
# :' metadata={'source': 'content.sorted.csv', 'row': 48, 'course_name': '統計學（一）', 'teacher': '陳立榜'}
# page_content='course name: 統計學（二）
# semester: 112-2
# teacher: 陳怡如
# reflection: 陳怡如老師的上課也超讚，老師上課會錄影，不會的觀念還可以回去看（我都拿來考前抱佛腳），講義也非常的詳細。不定期點名，小考兩次各10%，期中期末各30%，而且滿分都是130，有不小的容錯空間。相比榜哥紮實的課，我大概只花1/3的努力程度就拿到同樣的分數
# rating: 成績94 涼度10/10 甜度8/10
# :' metadata={'source': 'content.sorted.csv', 'row': 49, 'course_name': '統計學（二）', 'teacher': '陳怡如'}
# page_content='course name: 微積分甲
# semester: 112-1/112-2
# teacher: 林俊良
# reflection: 上課不點名，每堂課都有作業，考試也蠻難的，總成績都會大調分，想挑戰自我再選。
# rating: 成績88/82 涼度5/10 甜度5/10
# :' metadata={'source': 'content.sorted.csv', 'row': 50, 'course_name': '微積分甲', 'teacher': '林俊良'}
# page_content='course name: 四234 大學英文（一）（二
# semester: 112-1/112-2
# teacher: 郭曉蓉
# reflection: 大學英文應該都大同小異，但老師上課很有趣而且課程規劃很好玩，對英文很差（正是在下）的人也是很友善，是能拿高分的一門外文通識！建議每堂課都要到，老師會不定時點人回答（有點變相點名
# rating: 成績91/94 涼度9/10 甜度8/10
# :' metadata={'source': 'content.sorted.csv', 'row': 51, 'course_name': '四234 大學英文（一）（二', 'teacher': '郭曉蓉'}
# page_content='course name: 國文古典詩選讀
# semester: 112-1
# teacher: 許逢仁
# reflection: 許老師上課很有活力，而且會與同學一起感受詩作的情境。每堂課都點名，期中作業跟期末報告非常硬，期末報告一萬字，我覺得我花了很多時間但沒有得到相對的好分數。期末考試是申論題，也不怎麼容易。老師第一堂課就說這堂課很不容易了，我只能說我自作自受吧
# rating: 成績82 涼度2/10 甜度2/10
# :' metadata={'source': 'content.sorted.csv', 'row': 52, 'course_name': '國文古典詩選讀', 'teacher': '許逢仁'}
# page_content='course name: 社會學動動腦
# semester: 112-2
# teacher: 陳宗文
# reflection: 本課前兩節是老師授課，第三節是助教課。老師的課基本上就是簡介社會學的觀點，有時候圖畫欣賞多到讓我以為是藝術欣賞課。助教課是分組討論，每堂助教課都會點名，助教也會一起參與大家對於社會學的各種看法。作業蠻簡單的，期末展演是一組做一個海報。個人認為這堂課蠻有趣好玩的，而且可以認識很多新朋友！
# rating: 成績88 涼度7/10 甜度8/10
# :' metadata={'source': 'content.sorted.csv', 'row': 53, 'course_name': '社會學動動腦', 'teacher': '陳宗文'}
# page_content='course name: 誰來審判？國民法官就是你
# semester: 112-2
# teacher: 陳柏良
# reflection: 老師上課會帶著我們對於一些法律觀念的思辯，給大家討論跟激發不同的看法。期中會有模擬法庭，是請台北地方法院的法官來主持。整個模擬劇本很擬真好玩，案情的撲朔迷離需要考量各方面，這也讓我一改對法官的看法；期末是一組（約20人）一起打一遍一萬字的心得還有分享，整體負擔不大。對國民法官有興趣的同學可以修，大推！
# rating: 績88 涼度9/10 甜度8/10
# :' metadata={'source': 'content.sorted.csv', 'row': 54, 'course_name': '誰來審判？國民法官就是你', 'teacher': '陳柏良'}
# page_content='course name: 動物權：理論與實踐
# semester: 112-2
# teacher: 盧倩儀
# reflection: 兩週上一次。這堂課基本上就是宣導素食主義，殺生很殘忍也對地球不好這些的。修這堂課必須要去狗場服務一次，很好玩而且可以看到卓媽媽為了流浪狗付出的故事，我覺得很感動也很敬佩。偶爾點名，考試五次都是線上考，每堂課結束也會有一個作業（300～600字），基本上都是反思現實生活我們如何對待動物，還蠻容易的。
# rating: 成績94 涼度9/10 甜度9/10
# :' metadata={'source': 'content.sorted.csv', 'row': 55, 'course_name': '動物權：理論與實踐', 'teacher': '盧倩儀'}
# page_content='course name: 國文
# semester: 112-1
# teacher: 古育安
# reflection: 中文系乙班必修國文的其中一位導師，基本上一上課就會點名，遲到和缺席分別扣1、2分，甜度算是普通的一堂課，然後上課的時候滿涼的，基本上人有出席然後不要早退都還好。期中期末是以老師上課的PPT內容為架構，會考得非常細，基本上參照高中國文讀可能會考比較高分。作業的部分只有作文和論文（論文字數以小組人數論斷，若1人組別3000起跳即可，2人則6000起跳，以此類推），老師很看重論文格式和資料來源，如果紕漏太多論文可能直接不及格。整體負擔而言算小，不過撰寫論文的那一個多月會比較耗心力，建議提早開始準備且慎選組員。
# rating: 甜度：3 涼度：3 時間：二234 （112-1） 成績：85-89（期中20%、期末30%、作文10%、論文報告10%、論文成品20%、出席10%）
# :' metadata={'source': 'content.sorted.csv', 'row': 56, 'course_name': '國文', 'teacher': '古育安'}
# page_content='course name: 大學英文（一）（二）
# semester: 112-1/112-2
# teacher: 金嘉炘
# reflection: 以前版上著名的甜涼課，被通識中心提醒過甜度下降不少，但整體而言還是頗輕鬆。上課基本上完全是小組作業，僅有少數個人作業，且多半可在課堂完成，因此不會有太多負擔。老師上課不會使用課本，多半是以自己的PPT與講義為主，如果是認真想要鍛鍊英文可能比較不適合本堂課。上學期主要是讀寫，下學期是聽說，因此下學期可能沒有期中期末，但會有兩次小組口頭報告。
# rating: 甜度：3.5 涼度：4 時間：三D56 成績：85-89、90-94
# :' metadata={'source': 'content.sorted.csv', 'row': 57, 'course_name': '大學英文（一）（二）', 'teacher': '金嘉炘'}
# page_content='course name: 刑法（一）（二）
# semester: N/A
# teacher: 陳志輝
# reflection: 想選讀刑法的同學應該對老師多半有所耳聞，算是從教課方式到教課內容都很有一套自己想法的老師。老師強調以翻轉教室上課，因此課程內容會以影片預習＋每周繳交預習筆記的內容做為課堂討論的媒材，課程老師對於討論比較「有想法」，可能對這部分要做好心理準備。如果不怕被念、沒有社恐又很閒的話可以挑戰看看。
# rating: 甜度：3 涼度：1.5 時間：三234 成績：85-89、85-89
# :' metadata={'source': 'content.sorted.csv', 'row': 58, 'course_name': '刑法（一）（二）', 'teacher': '陳志輝'}
# page_content='course name: 語言學概論
# semester: 112-2
# teacher: 宋韻珊
# reflection: 上課算有趣且人滿好的老師，會盡可能簡化語言學的內容，然後想辦法介紹到同學清楚。上老師的課不太需要擔心基礎知識不足，不過上課過程可能需要比較專注，也有需要動筆的部分。除了期中期末外，會需要繳交一份「小報告」，從題目公布到繳交約莫三週，如果對語言學很有興趣（或是想要拚高分）可以做大一些。
# rating: 甜度：4.5 涼度：3.5 時間：二D56（112-2） 成績：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 59, 'course_name': '語言學概論', 'teacher': '宋韻珊'}
# page_content='course name: 民俗與文學
# semester: 112-2
# teacher: 楊明璋
# reflection: 上課老師不太點名（但老師說他看得出來誰沒到），如果被抓到缺席3次會被當。老師會從民俗為何開始介紹，接著介紹各類作品中的民俗與其作用。本門課沒有期中考，但有期中參訪（本學期是保安宮、慈聖宮，老師還有請點心），期末考則是偏向活用民俗相關知識的考題，因本堂課為與華語文教學學程合開課程，因此上課老師也會帶到相關概念。有3次作業＋一次小組口頭報告＋口頭報告的紙本報告（以論文格式為佳）。上課老師不給使用3C產品（紀錄或查詢除外），但其實也沒到完全禁止，仍有些自由空間，且上課知識量非常多，若對民俗有興趣不至於到沒有3C就會無聊到死的程度。如果對民俗、民俗相關作品很有興趣大推這堂！
# rating: 甜度：4 涼度：2.5 時間：三78E（112-2） 成績：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 60, 'course_name': '民俗與文學', 'teacher': '楊明璋'}
# page_content='course name: 經濟學
# semester: 112-1
# teacher: 陳心蘋
# reflection: 由於這門是我上學期上的課，一些資訊可能會記錯、還望不吝指正！這門課會不定期點名加分，期中期末考各一次，期中期末考前一周也各有一次小考，每週也會有作業需要寫課本上的指定題目並上傳pdf檔到moodle，這次每週也開了三個中午的助教課可以選擇自己方便的時段去，會記名加分。由於上學期後學家裡發生重大變故、又身體也因某些緣故動了手術，所以助教課都沒去，只去了考試，整學期只出現過五次（1次開學、2次小考、各1次期中期末），所以能得到這個分數已深感德便。大體而言，是一門可以自己決定想要學到什麼程度的課。
# rating: 甜度：3/5 涼度：5/5 推薦程度：3/5 分數：75
# :' metadata={'source': 'content.sorted.csv', 'row': 61, 'course_name': '經濟學', 'teacher': '陳心蘋'}
# page_content='course name: 大學英文（一）
# semester: 112-1
# teacher: 金嘉炘
# reflection: 這堂課和其他大學英文不同的地方在於，考試、背誦特別地少，老師認為背單字這種事，我們自己來就好了、沒必要再用上課和考試來教我們單字，所以這堂課每一次上課，都有課堂小組討論、課堂小組作業需要完成，比起其他英文課，更著重在訓練用英文討論及思考各種問題，惟有時候會不太懂老師課堂作業的形式，但問題不大，只要願意問、老師都會很願意解釋清楚。出缺席會納入計分，總共有三次小考，老師非常歡迎大家下課去找他確認截至當前的成績，非常適合會有成績焦慮的朋朋，可以讓你一直確認自己目前的情況。
# rating: 甜度：3.5/5 涼度：3/5 推薦程度：3/5 分數：83
# :' metadata={'source': 'content.sorted.csv', 'row': 62, 'course_name': '大學英文（一）', 'teacher': '金嘉炘'}
# page_content='course name: 民族語言學概論
# semester: 112-1
# teacher: 劉子愷
# reflection: 這堂課推薦給想要接觸語言學、語言人類學、人類學家的朋朋，老師是一名完整受過學碩博各階段人類學訓練的語言人類學家（這部分記錯的話再麻煩指正），整學期的課更像是「介紹語言學」和介紹一些語言人類學的東西，不輕鬆但我相信對這有興趣的人都有能力可以解決課堂的Loading，老師很開放、很能接受不同的觀點，也很願意花時間和學生聊聊遇到的問題和想法。每週都有指定閱讀文本、要小組討論問題提問，也會有導讀組講解文本，導讀組或老師會回答問題，基本上每週有讀完文本就可以了。期末考會發題目，讓大家自己回家用電腦寫，也有小組跟個人報告（報告的主題比較自由，只要跟上課的東西有關並和老師討論，老師應該都能接受），這堂課也需要自己找和課程有關的演講來聽一次，有助教課要參與，時間不行的老師也會另外想辦法處理（我是上線上的助教課），是個認真教學的老師。推薦給跟我一樣喜歡爆肝搞死自己的朋朋，認真的話能學到很多新知識、思考到許多未曾想過的問題，老師也很願意售後服務讓大家諮詢。
# rating: 甜度：4/5 涼度：1/5 推薦程度：4/5 分數：94
# :' metadata={'source': 'content.sorted.csv', 'row': 63, 'course_name': '民族語言學概論', 'teacher': '劉子愷'}
# page_content='course name: 大學英文（二）
# semester: 112-2
# teacher: 金嘉炘
# reflection: 這學期和上學期不同的點在於，原先的期中期末考試改成了兩次小組口頭報告，其餘形式（注重課堂討論、三次小考、歡迎大家隨時看成績等）大致相同，在此不多加贅言，這學期比起上學期更有實際去做的感覺，老師分享了許多實用的英文簡報、論述技巧。組員不要太雷，基本上不會有大問題。
# rating: 甜度：4.5/5 涼度：3.5/5 推薦程度：4/5 分數：91
# :' metadata={'source': 'content.sorted.csv', 'row': 64, 'course_name': '大學英文（二）', 'teacher': '金嘉炘'}
# page_content='course name: 中國神話選讀
# semester: 112-2
# teacher: 高莉芬
# reflection: 拜託大家都去上莉芬老師的神話課，每個星期心靈都會更加富足，她也非常關心學生，推爛。作業的話，要從老師的書單選一本和神話學有關的專書、經典來讀，每週寫心得（雖然會打分數，但基本上也不用太有壓力，有盡力寫就可以了），期中會有小組宮廟田野體驗，因為我本來就對台灣宗教跟民俗相關的事物甚感興趣，所以去廟裡真的讓我很開心，如果真的真的不能去廟的朋朋也可以和老師說，老師也會想辦法​，期末則是要選擇一個主題的神話報告。期末還有一個書面報告，可以是整本書的心得報告，也可以是期末神話報告的主題，按照老師要求的學術格式撰寫。整體上課的感覺，不會是那種看著文言文發呆的窒息時刻、慧根太淺難以參透的禪門公案，而是不斷地從文本、從神話衝擊我們的知識體系、甚至心靈的一場饗宴，後學受益匪淺，認真上這堂課真的不會後悔。
# rating: 甜度：4/5 涼度：2/5 推薦程度：6/5 分數：91
# :' metadata={'source': 'content.sorted.csv', 'row': 65, 'course_name': '中國神話選讀', 'teacher': '高莉芬'}
# page_content='course name: 知識型網紅面面觀
# semester: 112-2
# teacher: 方瑾
# reflection: 算是很輕鬆、但也學得到東西的一門三學分通識。老師的專長是華語教學，曾經經營過華語教學的Youtube頻道，但這堂課真的就是非常通識的通識課，沒有艱澀的理論，前半段會是老師講東西，後面會分組討論老師提出的問題，分組沒有固定，就很free地找坐附近的同學就可以了，老師非常能接納大家的想法，縱使提出的想法或發言有些尷尬，也能很好很圓滑地幫大家下台階，很暖。會點名、有兩份期中頻道觀察報告、一次期末頻道規劃報告，認真做一下就好了。推薦給想了解網紅、華語教學、數位民族誌、或想要學得到東西又不想太累的朋朋。
# rating: 甜度：4.5/5 涼度：4.5/5 推薦程度：5/5 分數：94.85
# :' metadata={'source': 'content.sorted.csv', 'row': 66, 'course_name': '知識型網紅面面觀', 'teacher': '方瑾'}
# page_content='course name: 生命探索與宗教文化
# semester: 112-2
# teacher: 林佩瑩
# reflection: 這堂核通聽老師所言，應該是宗教所的老師們輪開的，所以下次修到佩瑩老師開的這門課不知道會是什麼時候。這門課前半段很硬、後半段輕鬆很多，前半段會帶一些宗教學、宗教社會學、宗教心理學等與宗教相關的理論，每次課堂開始都有小考，但私以為只要上課有聽過一遍，基本上這些申論題目都非常簡單，前半段在期中考結束後，變成會有講者來演講並且要互動的演講課，但請來的講者也都臥虎藏龍，也很有收穫與啟發。最後會有一週的分組報告，要按照課堂上到的東西，應用學到的宗教相關理論來分析或看東西，時間有點小緊湊、要抓好報告時間。推薦給想要了解宗教，但不知從何下手的朋朋。
# rating: 甜度：5/5 涼度：3/5 推薦程度：5/5 分數：100
# :' metadata={'source': 'content.sorted.csv', 'row': 67, 'course_name': '生命探索與宗教文化', 'teacher': '林佩瑩'}
# page_content='course name: 當代台灣旅行文學欣賞
# semester: 112-2
# teacher: 張惠珍
# reflection: 這堂課時間允許才會開，上課老師會帶很多旅行文學的文本，基本上就是老師講、底下聽的聽在雲的在雲，或是有小貓兩三隻如我一直在回應，回答會加分，在講完之後老師會給大家題目，小組討論完可以上台分享，還挺有趣的，可以知道很多好玩的地方，讓你可以找到旅行的意義。會有期末書面報告（旅行文學專書心得及課程心得），及分組口頭報告要做，分組報告有分專題組、實體旅行組，專題組是虛構的旅行（像我這組就是以朝聖為主題，也有人報告拉麵），而實體旅行組要真的跟組員一起規劃然後去旅行，最後報告。但因為這學期大家上課不專心，所以接下來這門課應該會恢復考期末考。雖然大家上課都不太理老師，但老師是那種非常關心學生的麻麻型老師，會記得學生的變化等，也很樂意跟大家聊天，讓我覺得我不只上完了一學期的課，而是在漫漫人生路上多了幾個夥伴。推薦給對旅行文學、深度旅遊、想找新朋朋出去玩的人。
# rating: 甜度：4.5/5 涼度：4.5/5 推薦程度：5/5 分數：95.1
# :' metadata={'source': 'content.sorted.csv', 'row': 68, 'course_name': '當代台灣旅行文學欣賞', 'teacher': '張惠珍'}
# page_content='course name: 世界民族誌
# semester: 112-1
# teacher: 黃季平
# reflection: 這門課會介紹各個語系的民族，每週也都會有同學報告那週講的語系的民族，以專業課程來說，算是非常輕鬆的。每週要寫上課的心得，這堂課也會點名，可是除了心得和自己的口頭報告及書面報告外，沒有什麼額外的Loading，也不至於到完全學不到東西，還是可以學到一些有趣的冷知識，如果你是以一個系的專業必修來期望爆肝、學到很深的東西的話，這堂不要選，但如果你是外系缺專業課程學分的話，我極力推薦這門課，人只要有到、每週的心得都有寫、該做的東西做一做，都可以有不錯的分數，老師也很開放、很能接受不一樣的想法。
# rating: 甜度：4/5 涼度：5/5 推薦程度：4/5 分數：93
# :' metadata={'source': 'content.sorted.csv', 'row': 69, 'course_name': '世界民族誌', 'teacher': '黃季平'}
# page_content='course name: 詩選
# semester: 112-2
# teacher: 楊明璋
# reflection: 本門課有期中期末考（可以詢問老師範圍），課程內容算充實，作業部分有句讀、樂府詩心得、嵌名對聯、絕句一首（不強制）。
# rating: 甜度：4 涼度：2.5 成績：90-95
# :' metadata={'source': 'content.sorted.csv', 'row': 70, 'course_name': '詩選', 'teacher': '楊明璋'}
# page_content='course name: 三貓生態食農傳播實踐
# semester: 112-1
# teacher: 汪文豪
# reflection: 可以從老師上課感受到老師對於課程的用心，不過因為是首次開課，部分課程規畫應有再更細緻的可能，不過整體瑕不掩瑜。課程會有到後山踏查、到貓空實察以及到動物園參訪的移地課程，如果很注重準時上下課的同學不建議選課。學期中老師會請不少講師到教室分享，內容涵蓋生態、歷史、人文，如果對文山在地發展脈絡感興趣者應該會很喜歡本門課程。
# rating: 甜度：5 涼度：4 成績：95-100
# :' metadata={'source': 'content.sorted.csv', 'row': 71, 'course_name': '三貓生態食農傳播實踐', 'teacher': '汪文豪'}
# page_content='course name: 探索海洋－從水岸到深海
# semester: 112-1
# teacher: 陳建宏
# reflection: 基本上每週就是演講課的形式，會邀請海大不同教授到校上課，課程範疇從海洋生態、保育、漁撈、航運、重工業，主題算是滿發散的。每堂課結束後會需要繳交該週上課筆記（隔週發回），且本門課具有期中期末考（皆為上課PPT內容），可攜帶上課筆記作為參考資料。若想追求高分學期末可另外繳交一份小論文，主題不限（與海洋有關即可）。算是上課loading偏重的一堂課，但相對應的分數會不錯看。
# rating: 甜度：5 涼度：2 成績：95-99
# :' metadata={'source': 'content.sorted.csv', 'row': 72, 'course_name': '探索海洋－從水岸到深海', 'teacher': '陳建宏'}
# page_content='course name: 法學素養
# semester: 112-1
# teacher: 詹鎮榮
# reflection: 課程分為2小時正課及1小時助教課，分數主要來源為助教課發言次數及期末報告。適合考慮法律系雙輔的學生，內容紮實且助教帶討論有趣。
# rating: 甜度：4.5 涼度：4 成績：95-99
# :' metadata={'source': 'content.sorted.csv', 'row': 73, 'course_name': '法學素養', 'teacher': '詹鎮榮'}
# page_content='course name: 生命探索與宗教文化
# semester: 112-2
# teacher: 林敬智
# reflection: 是一堂正課偏涼的課，課堂一共寫三次心得跟一次期末團體報告，團體報告需要採訪跟上台，所以耗費的心力會比較多，建議慎選組員。助教課是團體討論、發表的模式進行，也滿注重發言次數。課程中可以感受到老師對於上課的熱情，不過台下有時候會get不太到，如果喜歡宗教應該會滿喜歡這堂課，老師上課會帶各宗教的文物來班上，有興趣可以去玩賞。
# rating: 甜度：4.5 涼度：4 成績：95-99
# :' metadata={'source': 'content.sorted.csv', 'row': 74, 'course_name': '生命探索與宗教文化', 'teacher': '林敬智'}
# page_content='course name: 慢速壘球初級
# semester: 112-2
# teacher: 王清欉
# reflection: 老師人很可愛，可以很明顯看出老師對於棒壘球的熱情。是一堂很注重分組的課，所以內向的人可能要審慎思考一下。基本上上課會點名，課程內容滿有趣（如果不排斥運動的話），不過要注意的是因為在室外上課，所以建議做好防曬措施。考試其實有點難度（先為我缺乏運動能力跟老師道歉）要有心理準備，不過還是推！
# rating: 甜度：3 涼度：3 成績：85-89
# :' metadata={'source': 'content.sorted.csv', 'row': 75, 'course_name': '慢速壘球初級', 'teacher': '王清欉'}
# page_content='course name: 民事訴訟法（一）
# semester: 1121
# teacher: 姜世明
# reflection: 老師人很可愛！我其實最有印象的是老師上基本論的時候，畢竟民訴是各方兵家必爭之地，老師從辯論主義的三大命題出發，對於後續的學習很有幫助。其實因為時間很少所以老師上學期只有帶過像當事人能力、訴訟標的理論跟一點點合併而已，感覺要上到老師的下整個民訴才會完整！給分很甜只是我沒有好好掌握，激推！
# rating: 甜度：4/5 涼度：3/5 推度：5/5 成績：88
# :' metadata={'source': 'content.sorted.csv', 'row': 76, 'course_name': '民事訴訟法（一）', 'teacher': '姜世明'}
# page_content='course name: 刑事訴訟法（一）
# semester: 1121
# teacher: 林麗瑩
# reflection: 老師給分真的很甜，期末考佔100%，前一堂課會有「重點提示」。但我個人的體感是如果想要建構完整的刑訴體系這門課可能不太適合。老師上課的時候花超級大篇幅的時間在講相牽連跟實質上一罪、裁判上一罪，雖然應該是重點但我感覺我的理解還是蠻發散點狀的，而且老師容易跳來跳去，不知道現在在哪裡。所以強烈建議如果上麗瑩的課一定要配洗澡熊建立體系，不然頗辛苦。
# rating: 甜度：5/5 涼度：2/5 推度：2/5 成績：96
# :' metadata={'source': 'content.sorted.csv', 'row': 77, 'course_name': '刑事訴訟法（一）', 'teacher': '林麗瑩'}
# page_content='course name: 民法物權
# semester: 1121
# teacher: 張韻琪
# reflection: 老師第一次開物權，跟傳聞中一樣的可愛，在上課的時候會講一些使人會心一笑的笑話。涵蓋範圍相當廣且有完整的體系，老師上課超級認真，而且會畫圖輔以說明（很好奇東大畢業的老師是不是都很會畫，不過畫工略遜士軒一籌）。大概是近年少有打破瑾瑜排一的老師，好課必推！
# rating: 甜度：4/5 涼度：3/5 推度：5/5 成績：81.5
# :' metadata={'source': 'content.sorted.csv', 'row': 78, 'course_name': '民法物權', 'teacher': '張韻琪'}
# page_content='course name: 商事法總論及公司法
# semester: 1121
# teacher: 朱德芳
# reflection: 老師上課應該算還蠻生動的，會有很多會計知識輔助學習，更了解公司內部的運作狀況。老師也會用很多實際案例輔助學習。每週都有加分機會可以寫，如果全寫的話應該分數不會太低，有兩次分組報告作業，所以對於不希望全押期末考的人而言很適合！但我必須老實說朱老師的上課方式不是很適合我，就我自己可能還是比較期望透過整體去理解，所以自己上課也沒有認真上、加分題也沒寫還有這個分數，我想應該是蠻甜的。
# rating: 甜度：5/5 涼度：4/5 推度：3/5 成績：85
# :' metadata={'source': 'content.sorted.csv', 'row': 79, 'course_name': '商事法總論及公司法', 'teacher': '朱德芳'}
# page_content='course name: 保險法
# semester: 1122
# teacher: 葉啟洲
# reflection: 保險法巨擘完全無話可說，真的是令人想拍桌的表現。主要是期中考我自己可能沒有把爭點全部抓出來加上表現不好，導致期中考分數表現不佳，不然的話應該是實打實分數派，如果很有實力的同學應該會拿到不錯的分數。老師會有體系的把保險法的重要內容帶過，然後也會講一些實務上的爭點、歷史上金管會跟立法者的處理方式。所以會很清楚為什麼會這樣規定以及這個規定哪裡有瑕疵的來龍去脈，好課推推！
# rating: 甜度：3/5 涼度：3/5 推度：5/5 成績：78
# :' metadata={'source': 'content.sorted.csv', 'row': 80, 'course_name': '保險法', 'teacher': '葉啟洲'}
# page_content='course name: 行政法（二）
# semester: 1122
# teacher: 陳靜慧
# reflection: 大二下學期因為跟數位系統衝堂所以改到這學期修。去年的經驗就是這堂課很吃助教（因為助教題佔總成績50分），行政法（一）的助教讚到不行，但聽說上學期的助教可能表現的不太理想，所以原本其實有點擔心助教的狀況會影響本課程的評價。結果就是白擔心了，我要告白助教，有夠好笑又有料，超級喜歡...正課的話就是我覺得如果認真嗑陳敏應該對於老師的進度跟節奏都有很不錯的掌握，再加上今年老師破天荒把投影片放在姆豆上跟期末送分題，整體甜度跟掌握度又比行政法（一）時再提升（不過分數倒是沒有長進），好課推推但吃助教，感覺可以先打聽一下今年助教是誰再決定要不要選。
# rating: 甜度：4/5 涼度：3/5 推度：4/5 成績：92
# :' metadata={'source': 'content.sorted.csv', 'row': 81, 'course_name': '行政法（二）', 'teacher': '陳靜慧'}
# page_content='course name: 計算機結構與組織
# semester: 1121
# teacher: 彭彥璁
# reflection: 在這個高階語言跟ChatGPT生Code的年頭學組合語言跟記憶體怎麼搬來搬去，感覺是有種返璞歸真的感覺。我覺得這門課「本身所要學的東西」是蠻有趣的，了解電腦加法乘法怎麼做，具體lw, sw, slt怎麼在電腦裡被跑等等。不過老師上課就比較多照本宣科，我自己後來就讀張凡了，所以如果沒有必修壓力或許自己讀也是一種做法...？有兩次組語作業然後要讀書，考試可以帶小綠卡背後可以抄小抄。
# rating: 甜度：3/5 涼度：2/5 推度：3/5 成績：77
# :' metadata={'source': 'content.sorted.csv', 'row': 82, 'course_name': '計算機結構與組織', 'teacher': '彭彥璁'}
# page_content='course name: 物件導向程式設計
# semester: 1122
# teacher: 紀明德
# reflection: 這門課我最想講的是助教，把過往的羊吃草拿掉改了一個全新的RPG遊戲，寫出來好玩又有成就感，真的是太用心了（雖然hw7因為期末考太擠了根本沒有時間寫後來就放掉）。我覺得老師很可愛而且也很願意分享自己過去寫程式的一些經歷，也會用一些生動的話語做比喻。如果真要說有什麼缺點大概就是全面上機考。以往CP1跟CP2雖然也有但是會配一張筆試卷平均。但全部上機考就真的很吃Debug能力跟當下狀態。我最後只拿了100分最大的原因就是我第2題有個致命的bug不會噴錯然後找了1.5小時還找不出來，最後真的是越急越找不出來最後就這個分數，然後因為沒有東西可以平均所以總成績不是太理想。我會說風險有點高...（最後發現是在某個動作裡重新宣告新的變數，超白癡...）
# rating: 甜度：2/5 涼度：1/5 推度：4/5 成績：74
# :' metadata={'source': 'content.sorted.csv', 'row': 83, 'course_name': '物件導向程式設計', 'teacher': '紀明德'}
# page_content='course name: 自然語言處理
# semester: 1122
# teacher: 黃瀚萱
# reflection: 先講如果想知道生成式AI在做什麼這堂課只有20%在教這個，如果想了解推薦可以看台大李宏毅教授的播放清單。這門課要從盤古開天講起，從tf-idf跟樸素貝氏分類器一直講到transformer跟LLM。畢竟自己是搞法學資訊的這門課對我是受益大良多，但對其他人我覺得就不太一定。這門課會需要機率論知識跟基礎python能力、可能還會需要一點人工智慧跟機器學習的基礎。有三次個人作業跟一次分組報告，我們這組train出來的模型效果超級差不知道在噴什麼，最後還有這個分數，真的太甜了。老師是大神，真的，如果去挖應該可以挖到很多東西，大推。
# rating: 甜度：5/5 涼度：2/5 推度：5/5 成績：88
# :' metadata={'source': 'content.sorted.csv', 'row': 84, 'course_name': '自然語言處理', 'teacher': '黃瀚萱'}
# page_content='course name: 資訊專題
# semester: 1122
# teacher: 劉昭麟
# reflection: 這門課我覺得最主要分享的就是老師，結論就是劉老師大推，雖然大部分的資科系學生在做專題前會先上過機率論，然後評價可能都不會到太理想。但修完資訊專題才真的懂為什麼：老師在上機率論的時候有點太在乎全班狀況了，導致於大家可能會覺得課程安排不盡理想，講到太多其他的事情。不過如果是要咪挺這個問題就完全消失了，基本上我跟劉老師的合作模式就是我這週決定要解決什麼問題然後劉老師教我、給我意見（意見都是超實用的那種），我在研討會發表當天老師還親自蒞臨指導報告的方式以及海報的細節。基本上老師就會完全因材施教，你的程度跟狀況目前到哪裡就講什麼。我覺得對老師的肯定就是國科會指導老師最多收兩名學生，啊劉老師今年兩名學生全上，所以真的不用多說。至於拿這個分數可能要感謝AI跨域研究計畫以及國科會計畫的肯定，這堂課修完一學期的成果包含補助被抖內了10萬左右，果然時間跟其他科的分數沒有不見只是集中到自己喜歡的事情上了...
# rating: 甜度：? 涼度：? 推度：5/5 成績：99
# :' metadata={'source': 'content.sorted.csv', 'row': 85, 'course_name': '資訊專題', 'teacher': '劉昭麟'}
# page_content='course name: 離散數學
# semester: 1122
# teacher: 張宜武
# reflection: 張媽就是推啦！這門課涵蓋的範圍包含算數、遞迴、關係跟圖，張媽講課會有一種和藹可親把很多概念解釋很清楚的感覺，而且張媽講英文實在是太舒服了不會有口音很好理解的那種（甚至上排列組合都不知道是不是在上英文課），小考每週考但只取五次最高，而且真的很簡單（問10枚不同硬幣翻到5個正面可能性有幾種的）。我真的要大感謝張媽（開學之後想寫卡片的那種），因為其實上面的研究有很重要的演算法概念跟定義是這學期圖論才學到的，完全沒想到知識可以這麼實戰實用...總之是實用又好玩，而且又學到很多東西的一門課。
# rating: 甜度：4/5 涼度：3/5 推度：5/5 成績：85
# :' metadata={'source': 'content.sorted.csv', 'row': 86, 'course_name': '離散數學', 'teacher': '張宜武'}
# page_content='course name: 初級會計學（ETP）
# semester: 112
# teacher: 黃政仁
# reflection: 問就是不甜又不涼，其實我不太知道其他班都怎麼上課或是內容大致如何，我覺得有達到我的初衷（了解財報大致上在幹嘛），但是坦白說有過量的分組報告作業小考真的是還蠻吃力的，我後來有想過可能大一商學院就這幾門必修所以本科應該還蠻友善的，但對於外系本身負擔偏重的就可能要考慮看看。每週都有作業，考4次小考、2次期中考跟今年加考的大會考，然後期中期末各一次分組報告。我了解老師的用心良苦不過當別人考完試放假開始玩還有一份股價預測的報告要做真的會做到EMO（前面都在期末考月根本不可能寫）。老師的名言佳句是 The evaluation of this class is higher than the Chinese class. Maybe I should speak more English，大家自行斟酌要不要修ETP。
# rating: 甜度：2/5 涼度：2/5 推度：2/5 成績：81/75
# :' metadata={'source': 'content.sorted.csv', 'row': 87, 'course_name': '初級會計學（ETP）', 'teacher': '黃政仁'}
# page_content='course name: 經濟學
# semester: 1121
# teacher: 廖仁哲
# reflection: 這門課因為是專門開給法律系的，所以基本上沒什麼數學，聽起來好像是優點但對我來說不盡然是如此，我覺得一直看圖對我來說比起給我數學公式吸收要來的困難的許多，導致最後是自己看書。不過自己看書也沒有抓到重點所以就也沒有表現很好，所以就只能說自己自作自受啦。上課會點名，有幾次作業跟考一次期中、一次期末。
# rating: 甜度：3/5 涼度：4/5 推度：2/5 成績：71
# :' metadata={'source': 'content.sorted.csv', 'row': 88, 'course_name': '經濟學', 'teacher': '廖仁哲'}
# page_content='course name: 經濟學
# semester: 1122
# teacher: 黃台心
# reflection: 老師基本上就是照著投影片一直唸，剛開學因為有上學期經濟學的教訓所以我還蠻認真在聽課的。直到因為我跟我的室友修同一門經濟學然後他都沒有去上課，結果期中考的比我高之後，我就問他都是怎麼唸的，他就說他都考前自己唸教科書就跟看作業就去考，所以我下半學期就再也沒去過了（最後我大會考考的比他高分，感謝我室友）。可能經濟學真的是我的罩門吧因為上了兩學期真的都有一段時間聽過課也有自己看書學但就是沒有抓到怎麼唸，所以才這個分數。這門課會有幾次作業，助教會在事前講解答案然後就可以作（ㄔㄠ）答（ㄒㄧㄝˇ），所以甜度涼度應該真的不錯。版上頗多人在推但我個人主觀還是不推，我覺得應該我問題比較大，這部分參考就好。
# rating: 甜度：4/5 涼度：4/5 推度：2/5 成績：72
# :' metadata={'source': 'content.sorted.csv', 'row': 89, 'course_name': '經濟學', 'teacher': '黃台心'}
# page_content='course name: 金融數量
# semester: 1122
# teacher: 江彌修
# reflection: 甜度的部分期中期末各考一次試，我都考65最後成績92，應該算是還蠻甜的。老師講的很不錯，不過有的時候會用一些很抽象的詞去描述（比如說：你要有你自己的風格，這我完全沒辦法心領神會）。本課程的編排是先講矩陣運算、向量空間，然後進到直和、內積空間跟正交。我自己還是比較習慣從向量空間開始讀起，所以編排也是可以斟酌的點。總的來說我覺得老師人很好，而且認真聽會學到蠻多東西，就是要想辦法跟上，可能課後還需要唸點書。
# rating: 甜度：5/5 涼度：3/5 推度：4/5 成績：92
# :' metadata={'source': 'content.sorted.csv', 'row': 90, 'course_name': '金融數量', 'teacher': '江彌修'}
# page_content='course name: 游泳中級
# semester: 1122
# teacher: 李慧婷
# reflection: 就是中規中矩的體育課，好像沒有特別的。前半學期會調姿勢，後半學期就是每天會有課表要游游完就上岸，實際課程時間如果自己游就會變大概一小時。前面有一次游800是體感真的會累，但其實後面習慣老師的強度就會越來越適應。今年很幸運幾乎沒有遇到寒流所以都游的很爽，好課推推！
# rating: 甜度：4/5 涼度：2/5 推度：4/5 成績：86
# :' metadata={'source': 'content.sorted.csv', 'row': 91, 'course_name': '游泳中級', 'teacher': '李慧婷'}
# page_content='course name: 國文一中國語言文字名作選讀
# semester: 1121
# teacher: 呂昭明
# reflection: 當初爬文找不太到這堂課的資訊，找到的評價都是說課程難、不甜，所以當時我填在偏後面的志願序，最後是遞補上的。不過上了課之後覺得比我想的好很～多！如同老師說的，課程內容跟以往上過的國文課都不一樣，很新鮮很有趣！推薦給不想讀詩詞或小說的人，個人覺得這點很棒🌟雖然老師說只要上課來聽課就好，這樣就不會佔用課外時間複習，但我覺得回家真的要讀一下，不然身為第一次接觸這些內容的人，會有點抓不太到方向，期中期末和小考都是選擇題，但偏理論，所以也需要花一點時間背。整個學期只有兩個作業，約在期中前後，都不算很難。上課超級涼，真的只要聽課就好，沒有分組或討論等等，社恐人可以放心選。上這堂課建議帶平板，看講義和做筆記都會比較方便～另外，感覺老師對語言和語言學似乎頗有研究，光是聽課就感受得到他的熱忱，respect！若是對這方面有興趣的人，或許可以跟老師聊聊，應該會蠻有收穫。還想再補充個很加分的point，老師的個性非常親切可愛，下課時有人問他問題都會耐心回答，上課偶爾會穿插一些有點好笑的梗，魔性笑聲也很有趣哈哈哈，總之是一個可愛老師，推推！
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 92, 'course_name': '國文一中國語言文字名作選讀', 'teacher': '呂昭明'}
# page_content='course name: 大學外文（一）（二）：西班牙文
# semester: 1121/1122
# teacher: 李文康
# reflection: 這堂課不涼，不能翹課、遲到，也不能做自己的事，不然會被扣分。甜度的話我覺得蠻OK的，大部分的人學期成績應該都8、90～收穫程度的話我給滿分，這堂課有很多練習的機會，讓我口說進步非常多！課程內容基礎且實用，會從字母開始教，上課常常要找人練習對話，但是不會很難，第三堂課通常會一起唱歌，上課氛圍輕鬆快樂！期中期末都是紙本考試，通常都會比行事曆上訂的考試週提早一到二個禮拜考，成績不會調分，但是考試不會太難，所以不用擔心！如果你是願意遵守規定、上課不用手機也不會做其他事、願意開口練習且想要快樂學西文的人，非常推薦這堂課！
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 93, 'course_name': '大學外文（一）（二）：西班牙文', 'teacher': '李文康'}
# page_content='course name: 大學英文（一）
# semester: 1121
# teacher: 黃杏妃
# reflection: Kirsten上課是全英授課，下課談事情也是用英文，但老師的英文不會講的太難，連英文很爛的我都可以聽懂。上課主要上課本內容加課外內容，每一堂課幾乎都有組內討論，會請人分享看法，老師都很鼓勵大家回答，回答不太出來也會引導。然後每一堂課結束都有小作業，通常會於下一堂課要大家分享，雖然內容不難，但對於英文不好的人準備起來還是有點難度。一學期只有一次期末考，沒有期中考，有期中報告，報告是一整組上台報告，有兩次寫作作業，兩次口說作業。期末題目我覺得還好，聽力練習對我來說比較困難其他還好，或許一般人會覺得比較簡單一點。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 94, 'course_name': '大學英文（一）', 'teacher': '黃杏妃'}
# page_content='course name: 田徑
# semester: 1122
# teacher: 洪鈺釗
# reflection: 這堂課主要教跑步、鉛球跟跳遠，上課步調輕鬆，會實際操作這些動作，考試為100公尺、鉛球執遠跟跳遠，後兩者拿到好一點的成績不太難，上課有認真聽、一起操作應該都不會太差，而100公尺比較看自己的能力了。期末會有一個簡單的表單考試，是老師上課的內容，分數滿甜的。
# rating: N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 95, 'course_name': '田徑', 'teacher': '洪鈺釗'}
# page_content='course name: 武術初級
# semester: 1121
# teacher: 張仲豪
# reflection: 前幾周的課程老師會先花一些時間在教授跟修正同學暖身的動作。之後幾週大家對暖身組合比較熟悉後速度就會加快，變成正常的上課流程。平常上課大概會花將近半堂課的時間暖身+彈力帶走路環繞校園(每次走的路線不太一樣)，下半堂老師會教授三戰姿勢與基本拳法。個人覺得這堂體育最大的特點是老師放超多精力在調整大家的動作姿勢到正確的位置，每一個動作的發力點跟肌肉的位置應該要在哪都說明的超清楚，所以只要沒有恍神應該是不會有跟不上的問題! (如果有問題也可以下課的時候去問老師，老師一定有辦法讓你懂問題在哪還有應該怎麼調整)。而且我自己另外感覺很好的部分是老師有超多輔助教具，會透過教學經驗不斷改良更新，真的是你能感覺到他有多用心的一個老師。老師上課也常常會分享很多好笑的小故事，讓大家適時休息放鬆，但當中一定難以避免摻雜一些個人的立場或價值觀，我個人覺得每個人都有權利擁有各式各樣的想法和意見，就順順聽過去而已，而且老師也不會嘗試把自己的價值觀強加到大家身上。但這方面如果會「很」介意的人可以自己斟酌一下~
# rating: 甜度：4/5 涼度：2.5/5 成績：98 費用：500以下
# :' metadata={'source': 'content.sorted.csv', 'row': 96, 'course_name': '武術初級', 'teacher': '張仲豪'}
# page_content='course name: 大學英文（二）
# semester: 1122
# teacher: 戚大為
# reflection: 跟大學英文(一)的模式基本上相同，有興趣的人可以去找112-1選課心得看。分數就是完全靠自己打拼，上課抄筆記不要漏掉太多，作業認真寫、準時交，考試認真準備。考試怎麼拿高分其實他上課都有講，但難的是真的把他說到的每一個點都做好。但上了他兩個學期的大學英文是真的有感覺自己的進步，最直接的反應就是分數。班上的同學這學期口說拿到的成績和上學期相比都有滿多進步的，所以穩穩的跟著他的腳步，慢慢把他注重的點融入到自己的英文運用中，成績一定會越來越好看~
# rating: 甜度：未明 涼度：1.5/5 成績：95
# :' metadata={'source': 'content.sorted.csv', 'row': 97, 'course_name': '大學英文（二）', 'teacher': '戚大為'}
# page_content='course name: 國際關係
# semester: 1121
# teacher: 楊文琪
# reflection: 課程內容很充實，我自己基本上不太會睡覺或做自己的事，因為老師上課用的簡報不會另外給同學，也不能下一堂課去補拍(但如果有朋友或比較好的組員可以跟他們要筆記)。缺席可以直接讀課本，基本上老師上課的範圍都太不會超出課本，超過的部分考試也不考，不過老師簡報已經幫大家把課本統整好了，所以我還是建議上課認真作筆記比較好。考試滿分會超過100，所以成績應該不會太難看。我們這學期沒有校外參訪，但期中左右剛好有國際研討會，所以有一堂課是要出席研討會。小組報告：選一組非國家行為者做為主題進行小組報告。期中/期末考試：選擇題、是非題、申論題。
# rating: 甜度：未明 涼度：未明 成績：95.5
# :' metadata={'source': 'content.sorted.csv', 'row': 98, 'course_name': '國際關係', 'teacher': '楊文琪'}
# page_content='course name: 電影與國際關係
# semester: 1121
# teacher: 蔡增家
# reflection: 好多人推薦的課，上課蠻涼，就是聽他分享國際新聞跟國際歷史之類的，但老師好像很重視出席率，也會特別關注上課不專心的人。只有期末考，考前一週會洩題，但我寫起來還是有蠻多題不會@@ 還有上課要記得抄筆記！不用抄很多就每堂課記一些小重點。筆記好像是蠻重要的加分項，會算在平時成績裡。
# rating: 甜度：5/5 涼度：4/5 分數：95+
# :' metadata={'source': 'content.sorted.csv', 'row': 99, 'course_name': '電影與國際關係', 'teacher': '蔡增家'}
# page_content='course name: 醫療與生活
# semester: 1121
# teacher: 林志陵
# reflection: 非常涼，大部分的人上課都在做自己的事。老師會講一些醫學相關的東西，還蠻有趣的！出席10% （整學期隨機點名十次少一次扣一分）期中考20% 期末考70%，期中是寫電影心得（姊姊的守護者）期末是五題申論（題目：癌症預防、對於失智症/人口老化/高齡照護的想法、疫情期間的防疫措施、疾病帶給你的影響）
# rating: 甜度：4/5 涼度：5/5 分數：90-94
# :' metadata={'source': 'content.sorted.csv', 'row': 100, 'course_name': '醫療與生活', 'teacher': '林志陵'}
# page_content='course name: 預防醫學與校園健康
# semester: 1121
# teacher: 吳逸帆
# reflection: 一樣很涼，講一些跟日常生活有關的醫學和疾病常識，蠻實用的。整學期好像點名不到5次。考試範圍就是ppt最後面的重點整理，期中我覺得有點難（可能是因為我太爛@@）期末好像有簡單一點，但因為很多多選題（問你四個敘述中有幾個是正確的）錯一個就是全錯，所以我還是覺得很難、、、有上台報告，沒有主動加分，最後成績如上。版上蠻多人好像都是有發言然後拿95+ 所以感覺發言加分還是很重要！
# rating: 甜度：4/5 涼度：4/5 分數：90-94
# :' metadata={'source': 'content.sorted.csv', 'row': 101, 'course_name': '預防醫學與校園健康', 'teacher': '吳逸帆'}
# page_content='course name: 傳播法規與倫理
# semester: 1121
# teacher: 盧建志
# reflection: 很涼的一堂課，沒有考試，老師上課會分享一些和傳播產業有關的法規條例，我自己覺得滿有趣的！基本上是算出席分（我有請假一兩次、翹課被抓到一次@@）、上台報告分數還有期末的一兩項個人報告，我覺得loading完全不會很重，推薦對法律或傳播產業有興趣的人修～
# rating: 甜度：4/5 涼度：4/5 分數：90-94
# :' metadata={'source': 'content.sorted.csv', 'row': 102, 'course_name': '傳播法規與倫理', 'teacher': '盧建志'}
# page_content='course name: 語言與認知神經科學概論
# semester: 1121
# teacher: 賴瑤鍈
# reflection: 這堂課上課方式是前兩節課老師會上課然後偶爾會在zuvio上問問題。上課會點名。老師會幫大家分組，第三節會是小組討論，會開表單填答，有困難助教也會下來領導小組討論。期中的報告是做期末報告的概述，大概五分鐘左右。內容就是小組自己決定有關語言學的報告，基本上大家都是做要參考文獻或填表單的主題。期末就是完整的報告，沒記錯的話可能是15-20分鐘。小組之間和組員之間都會有互評表單，算出席成績所以就算自己沒報告也要去聽。上課的內容就是語言學和認知神經科學，有比較貼近生活的主題也會有比較專業的內容，認真上的話可以學到蠻多東西的。老師講話很有邏輯也很清楚，上課回答會加分。
# rating: 甜度：4/5 涼度：3/5 分數：90-93
# :' metadata={'source': 'content.sorted.csv', 'row': 103, 'course_name': '語言與認知神經科學概論', 'teacher': '賴瑤鍈'}
# page_content='course name: 窺探科技中的語言應用
# semester: 1121
# teacher: 張瑜芸
# reflection: 老師上課非常有趣！老師本人就很活潑搞笑，上課的內容都蠻貼近生活的，當然也會有一些比較專業的內容。上課方式是前兩節聽老師講課，跟學生的互動蠻多的，也有小組討論的部分，很積極帶動同學回答問題。第三節要帶筆電，會是助教帶大家用google colab 寫程式，但完全沒接觸過的人也不會有困難，因為助教都寫得很清楚，跟著一步步用完全沒問題！這堂課只有分組期末報告，也是主題自定，組別自己分。如果要選資訊通識的話非常推薦！
# rating: 甜度：4/5 涼度：4/5 分數：90-93
# :' metadata={'source': 'content.sorted.csv', 'row': 104, 'course_name': '窺探科技中的語言應用', 'teacher': '張瑜芸'}
# page_content='course name: 全球經濟與勞工問題
# semester: 1121
# teacher: 張其恆
# reflection: 老師上課基本不點名，除非人到得很少才會點（加分不扣分）只有期末小組報告，主題就是跟課程主題相關，除了上台報告還有書面報告（一組5000字）。認真聽是可以學到蠻多這樣。後面幾週都是小組報告，一次大概三組左右，一組20-30分鐘。建議可以看版上其他人的評價，論出席而言是蠻涼的，但甜度就因人而異吧🚬
# rating: 甜度：2.5/5 涼度：4.5/5 分數：85-88
# :' metadata={'source': 'content.sorted.csv', 'row': 105, 'course_name': '全球經濟與勞工問題', 'teacher': '張其恆'}
# page_content='course name: 語言的人文與科學
# semester: 1121
# teacher: 賴瑤鍈、張瑜芸、黃瓊之
# reflection: 我上的課的負責老師是張瑜芸老師（星期二的），但三個老師的課都會上到，只是負責聽報告跟評分的是這位老師。賴瑤鍈老師的課和張瑜芸老師的課跟上面寫的差不多，只是沒有那麼深入和沒有那麼跟寫程式有關，黃瓊之老師上課的內容也蠻有趣的，上課方式還好，但三位老師都蠻積極跟台下互動的！這堂課只有期末小組報告（老師分組）跟一面A4的期末心得報告，每節都會點名，第三節是助教課也會另外點名，會帶大家討論大概五個問題，對期末報告蠻有幫助的，助教也很用心，不會沉悶！我覺得算是很輕鬆的核通了，跟一般通識差不多。
# rating: 甜度：4/5 涼度：4/5 分數：90-94
# :' metadata={'source': 'content.sorted.csv', 'row': 106, 'course_name': '語言的人文與科學', 'teacher': '賴瑤鍈、張瑜芸、黃瓊之'}
# page_content='course name: 大學英文
# semester: 1121
# teacher: 余懿珊
# reflection: Connie真的是天使老師！作業和報告都給分很甜，每次基本上一上課就會點名，應該是算在加分項裡（不太確定）。老師是那種很認真上課，會希望學生真的學到能運用的東西的老師，上學期有點忘了，但這學期是期中考兩課+聽力，期末考一課+寫作+口試，題目內容在考試前一週會小小洩題，有時候上課也會特別說哪裡要注意。作業一學期有三個，還有三項要看學校給的影片的加分小作業（上學期不是加分，下學期改成加分作業）。報告的部份是一個小組期中報告而已！（更：上學期是一個個人報告和一個小組報告）。老師在下學期一開始就會根據同學們的意見問卷跟大家討論接下來一學期要如何改善，或者是有哪裡有更動之類的，所以可能上課方式和計分方式會變。真的是非常用心的老師。（私心希望如果選上這堂課的同學不要讓老師失望）。我個人是每節都有到，一般作業和加分作業也都有做這樣。
# rating: 甜度：5/5 涼度：3/5 分數：97-100
# :' metadata={'source': 'content.sorted.csv', 'row': 107, 'course_name': '大學英文', 'teacher': '余懿珊'}
# page_content='course name: 生命價值與哲學思惟
# semester: 1121
# teacher: 胡志強
# reflection: 老師人很好，鼓勵發言，強調課前閱讀文本討論而課後講述的模式。整學期要讀的文本其實沒有很多，只有幾篇心得和期末考。但若慧根不足佛教的部分將會感到十分痛苦，考試的時候也很難寫。老師的上課簡報比較難作為課後及考試複習內容，建議認真寫心得和多問助教問題和參與發言。
# rating: 甜度：3/5 涼度：4/5 分數：88
# :' metadata={'source': 'content.sorted.csv', 'row': 108, 'course_name': '生命價值與哲學思惟', 'teacher': '胡志強'}
# page_content='course name: 認識勞資關係與勞動權益
# semester: 1121
# teacher: 吳姿慧
# reflection: 老師是勞資關係相關的法律系老師，但上課內容平易近人，非法律系的同學也能輕鬆吸收，對往後職涯非常實用。平常基本上專心上課並課後看一下老師的簡報就可以了。成績以期中和期末考為主，但多為選擇題和少數實例題。實例題的部分建議記熟老師上課提及的實務見解，考試時能成功想起並用自己的話書寫再套用進題目提供的事實中就能拿到分數。
# rating: 甜度：4/5 涼度：4/5 分數：94
# :' metadata={'source': 'content.sorted.csv', 'row': 109, 'course_name': '認識勞資關係與勞動權益', 'teacher': '吳姿慧'}
# page_content='course name: 大學英文（二）
# semester: 1121
# teacher: 郭曉蓉
# reflection: 基本上前半段課程都會是聽同學的個人報告，可以做自己的事。後半段才會有主題互動團體討論，幾乎沒有回家作業。成績以個人報告，期中、期末考及期末報告為主，個人大學英文（一）並非修習本課，而是其他loading較重的老師。相較之下，若對英文沒有太大熱忱，建議早早免修英文或轉班。但大學英文基本上都是灌黨，所以不好加簽和選課，需自行斟酌。助各位身體健康，暑假愉快。
# rating: 甜度：3/5 涼度：5/5 分數：90
# :' metadata={'source': 'content.sorted.csv', 'row': 110, 'course_name': '大學英文（二）', 'teacher': '郭曉蓉'}
# page_content='course name: 大學外文(一)&(二)：日文
# semester: 1121&1122
# teacher: 詹兆雯
# reflection: 會用大家的日本語當教材。老師上課很扎實!除了概念之外其他部分(會話、單字)也會帶到，會有一些(不可謂不多)的補充。會需要上課練習，老師會要求跟隔壁同學練習句型或會話，最後點人示範，另外112-2開始會要編對話，就是利用學過的句型編一段日常對話。每周有單字小考跟作業(有一個表單，就是教材的題目練習)，然後也有期中期末，但不會到特別難。
# rating: 甜度：4/5 涼度：3/5 分數：89/92
# :' metadata={'source': 'content.sorted.csv', 'row': 111, 'course_name': '大學外文(一)&(二)：日文', 'teacher': '詹兆雯'}
# page_content='course name: 中國大陸概論
# semester: 1121
# teacher: 林義鈞
# reflection: 上課內容很豐富，基本上政治經濟社會都有講到，老師上課也很認真，可以學到很多東西，助教課氛圍也還算輕鬆，另外有指定教科書。作業有數次心得跟小組書面報告。心得就是閱讀完指定教科書特定章節的心得，書面報告也不會太難做。有期中期末，但期末可以帶參考資料(至少當時可以)。然後會有看電影跟演講，有寫心得可以加分。
# rating: 甜度：5/5 涼度：4.5/5 分數：98
# :' metadata={'source': 'content.sorted.csv', 'row': 112, 'course_name': '中國大陸概論', 'teacher': '林義鈞'}
# page_content='course name: 物理學史與人類文明
# semester: 1121
# teacher: 楊志開
# reflection: 上課會用英文ppt，並且不會另外給，所以需要聽課。內容上就是歷史發展跟當時期發現的物理概念，近似歷史課跟物理課的結合。有分組上台報告，有數個題目可以選擇，但必須引用到老師列的書單(皆是原文書)。有期中期末，有遇到物理概念題(所以考得不太好)。平常有一個（疑似不算分）的點名，但是點名方式是用一張小題目，有點類似期中期末的題型。
# rating: 甜度：3/5 涼度：5/5 分數：72
# :' metadata={'source': 'content.sorted.csv', 'row': 113, 'course_name': '物理學史與人類文明', 'teacher': '楊志開'}
# page_content='course name: 中國思想名作選讀
# semester: 1121
# teacher: 林啟屏
# reflection: 上課內容會有點哲學，然後同時有像國文課的文言文釋義。整體上有點難，但可以學到很多東西，可以感受到老師很博學。有分組上台報告，題材只要跟思想有關就可以，另外還有論文，題材也是跟思想有關就可以。有期末，是申論題。給分似乎都偏扎實。
# rating: 甜度：3.5/5 涼度：3/5 分數：83
# :' metadata={'source': 'content.sorted.csv', 'row': 114, 'course_name': '中國思想名作選讀', 'teacher': '林啟屏'}
# page_content='course name: 租稅與生活
# semester: 1122
# teacher: 徐麗振
# reflection: 上課有ppt，主要就是幾個常用稅別的介紹跟實際操作，講得還算清楚，同時會用若干實例讓同學知道怎麼應用條文，只是會上滿3小時，會有點累。有四次作業，都是上課介紹的稅法條文操作，個人覺得有認真看ppt就不會太難處理。會有隨機點名。
# rating: 甜度：4.5/5 涼度：4/5 分數：97
# :' metadata={'source': 'content.sorted.csv', 'row': 115, 'course_name': '租稅與生活', 'teacher': '徐麗振'}
# page_content='course name: 木球初級(男女合班)
# semester: 1122
# teacher: 王思宜
# reflection: 老師會講解動作，而且算蠻仔細的。之後就是長時間練習揮桿，主要是空揮跟倆倆互相擊球，期間老師會看每個人動作，同時會去糾正動作。期中是一公尺攻門，打十顆，有點難，但有不少練習機會。期末是分組排名賽。在操場上課，有時候會有點酷熱，但是下雨就到室內作一些體能。另外需要跑操場(1.5-1圈)。
# rating: 甜度：4/5 涼度：4/5 分數：86
# :' metadata={'source': 'content.sorted.csv', 'row': 116, 'course_name': '木球初級(男女合班)', 'teacher': '王思宜'}
# page_content='course name: 大學英文
# semester: N/A
# teacher: 王力英
# reflection: 一樣推薦想練口說的來👋 不一樣的是，上學期分組是整學期固定的，這學期是一個禮拜就重分一次組。我比較社牛所以還好，內向的人需要注意這點。loading 很輕，個人報告+小組報告，兩個都很小，幾乎是半小時能處理好的。期中期末各一次筆試，難度還好也沒得準備。老師很 nice，鼓勵進步。整體評價兩極，需多爬文。
# rating: 甜度：3.5/5 涼度：4.5/5 推薦度：4/5 成績：91
# :' metadata={'source': 'content.sorted.csv', 'row': 117, 'course_name': '大學英文', 'teacher': '王力英'}
# page_content='course name: 環視全球-挑戰國際視野
# semester: N/A
# teacher: 王韻
# reflection: 必須老實講，這堂課是目前我上到最問號的一堂課，到學期末了還是不知道這堂課要幹嘛。但教授人很好很親切，很樂意跟學生進行思想上的交流，這點我大推。課堂講國際關係課程，後半段弄小組專案，結果也很模糊。適合喜歡涼課的同學。
# rating: 涼度：4/5 推薦度：3/5 成績：N/A
# :' metadata={'source': 'content.sorted.csv', 'row': 118, 'course_name': '環視全球-挑戰國際視野', 'teacher': '王韻'}
# page_content='course name: 藥物使用與生活的關係
# semester: N/A
# teacher: 潘俊宏
# reflection: 很涼，每堂課點名但使用 QR code。期中期末各一次手寫報告，內容是個人看法，無標準答案。學期結束發現給分非常甜，雖然內容很空泛但輕鬆混學分。
# rating: 甜度：4.5/5 涼度：5/5 推薦度：2/5 成績：89
# :' metadata={'source': 'content.sorted.csv', 'row': 119, 'course_name': '藥物使用與生活的關係', 'teacher': '潘俊宏'}
# page_content='course name: 自主學習專題：機率與理則學在橋牌遊戲上的應用
# semester: N/A
# teacher: 張宜武 (實際授課：源宗老師)
# reflection: 上課主要是打橋牌，學期分數部分是根據牌局排名，腦力競爭激烈。期中期末皆為開書考試，難度不高但需跟上教學進度。老師熱情且樂於回答問題。
# rating: 甜度：5/5 涼度：5/5 推薦度：5/5 成績：91.2
# :' metadata={'source': 'content.sorted.csv', 'row': 120, 'course_name': '自主學習專題：機率與理則學在橋牌遊戲上的應用', 'teacher': '張宜武 (實際授課：源宗老師)'}
# page_content='course name: 桌球初級
# semester: N/A
# teacher: 謝明輝
# reflection: 課程友善於初學者，老師耐心手把手教學。課堂冷氣舒適，但早八課程對於起床困難者不太友善。期中、期末考試以及雙打比賽，遲到影響分數。整體適合有興趣學習者。
# ...
# rating: 甜度：5/5 涼度：4/5
# :' metadata={'source': 'content.sorted.csv', 'row': 950, 'course_name': '保險法', 'teacher': '葉啓洲'}
# page_content='course name: 民事訴訟法（二）
# semester: 112-2
# teacher: 劉明生
# reflection: 整體來說跟老師的民訴（一）沒有什麼差別，就是延續上學期的進度繼續講，考試方式也相仿，但個人覺得老師的字跡有非常明顯的進步🤩
# rating: 甜度：5/5 涼度：4.5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 951, 'course_name': '民事訴訟法（二）', 'teacher': '劉明生'}
# page_content='course name: 行政法進階
# semester: 112-2
# teacher: 詹鎮榮
# reflection: 這門課是因應行政法基礎課程改制兩學分後生出來的，主要在介紹行政罰法、國家賠償法以及行政執行法。詹爸的講課跟簡報一如既往的美觀優秀流暢，課程中請到行政執行署花蓮分署長來演講也超級有趣，考量到這門課涉及的三個行政法規都是國考常客，在研究所考試也有一定重要性，然後還是詹爸上課，真的要選起來！！考試只有一個期末考，是選擇題搭配一題實例題，可以帶法典跟最高行政法院的決議跟判決；然後上不完的部分會有影音檔補充，非常之窩心。
# rating: 甜度：5/5 涼度：4.5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 952, 'course_name': '行政法進階', 'teacher': '詹鎮榮'}
# page_content='course name: 刑事證據法
# semester: 112-2
# teacher: 何賴傑
# reflection: 顧名思義，這堂課主要著重在刑訴證據章的部分，老師一樣會介紹一些刑訴的基本原則，然後證據部分著重在講授傳聞法則、證人、被告自白及鑑定的新修法。上課會有簡報但蠻簡約的，幫助不大，主要還是聽老師講。內容比較強調一些重要的實務/學說見解，老師偶爾也會用吐槽的方式表達他的觀點，通常都還蠻好笑的XD個人覺得講得不算特別深入，但搭配課本還是可以加深印象，不過這堂課有開給大二，建議修過刑訴後再來上這堂課負擔會小一點。期中考、期末考都是選擇題，分別有25及50題，期末考難度較高、範圍較廣建議期中好好寫可以拉一點分數；然後老師班上的助教課一定要去，不管刑訴還是證據法的助教整理的體系圖跟記憶方法都非常實用，對於考試分數也有很大的幫助。
# rating: 甜度：5/5 涼度：4.5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 953, 'course_name': '刑事證據法', 'teacher': '何賴傑'}
# page_content='course name: 刑法（一）、（二）
# semester: 112-1, 112-2
# teacher: 謝如媛
# reflection: 老師的上課方式是用投影片，通常不點名，不過到下學期期中考後老師覺得很多人成績太糟，所以有時候會隨機抽點，但不知道有沒有影響學期成績。課程編排應該是以林鈺雄老師的教科書為主，會介紹其他學者的學說和自己的見解，並搭配許多重要的判決講解抽象的理論；老師的見解大多數與通說相同，也會詳細跟大家講解為什麼自己支持這項學說，並鼓勵大家多多思考。進度不會太快，不過我自己會再花滿多時間讀教科書，畢竟精熟刑總真的是一大挑戰QQ。考試方式是810題的選擇題加上23大題的實例題，個人覺得考試的給分相當明確，出題也不會太複雜，考前如果有熟讀理論、認真練習寫實例題應該就能拿高分（但我沒有）。雖然很多人都會特別推薦士軒老師的刑總，不過我覺得只是風格差異，個人很能接受如媛老師的上課及評量方式，而且老師個性很可愛、聲音很好聽（？），如果有人在士軒與如媛間猶豫，或是被灌檔到ㄓㄏ但怕選不到士軒，想在此推推如媛的刑總，一定能受益良多。不過老師常常偷臭柯文哲和黃國昌（上課到一半突然說「我有欠你喔」真的好好笑），如果是小草的話可以自行斟酌🥵。最後趁機告白助教，威齊我們愛你謝謝你一年來的課輔。
# rating: 甜度：🍬🍬🍬 涼度：🧊🧊
# :' metadata={'source': 'content.sorted.csv', 'row': 954, 'course_name': '刑法（一）、（二）', 'teacher': '謝如媛'}
# page_content='course name: 民法債編總論（一）
# semester: 112-2
# teacher: 王千維
# reflection: 老師的上課方式是白板書寫（就算筆沒水也會繼續寫），內容大多與王澤鑑老師的《債法原理》幾乎一模一樣，上千維的課務必要買這本書；在講解的過程中會加入自己的一些心得（？），也會穿插簡單的案例。老師會直接給出整學期的課程大綱，各個標題大多都能對應到王澤鑑老師書中的章節，書上的每一行字幾乎都會出現在課堂中（導致進度很慢），也因此到後期我都沒認真上課而是自己讀書QQ，老師洪亮的嗓音、凌亂的板書讓我有點適應不良，但老師給的大綱還是有幫助到我整理筆記。與其他班最不同的是！千維老師不會在債總一教債務不履行，導致我自己在理解案例上有點障礙，而且老師在畫關係圖的時候會把文字、條號和箭頭全部擠在一起，只要一閃神就會看不懂。不過個人認為千維的課非常甜＆涼！因為期中考是50題選擇題且幾乎都來自於考古題，只要稍微複習教科書並看過考古題，就能拿到分數（我考前一小時才看考古題得到90分）；期末考是兩題實例題，難度大概和王澤鑑老師書中的案例差不多，不會要求要寫出詳細的學說，可說是相當好拿分。這堂課公認的缺點應該就是進度真的有夠緩慢，上半學期會花很多時間介紹契約的種類、期中考後會不斷強調要約承諾的部分，不喜歡進度太慢或是對太細節的東西不感興趣的同學可能不太適合。
# rating: 甜度：🍬🍬🍬🍬🍬 涼度：🧊🧊🧊🧊🧊
# :' metadata={'source': 'content.sorted.csv', 'row': 955, 'course_name': '民法債編總論（一）', 'teacher': '王千維'}
# page_content='course name: 憲法
# semester: 112-2
# teacher: 林佳和
# reflection: 老師是用同影片搭配板書上課，原則上這堂課不太需要買教科書，因為就算看了應該也不知道佳和在講什麼點點點（非貶意）。佳和上課會講解非常多抽象的專有名詞和理論（並痛罵中國國民黨和某些他不喜歡的學者），講越久的越容易成為期末考考題，一開始因為根本聽不懂佳和在講啥所以沒認真聽課，到期末才發現代誌大條，建議大家上佳和的課不管聽不聽得懂反正先抄下來再說（但佳和的板書很藝術）。不確定怎麼推薦這堂課因為我是學渣點點點，可以確定的是佳和給分很甜，雖然自認為沒有寫爆但就是覺得自己的作答狀況有點荒唐，最後仍然拿到了80分，愛佳和。佳和在期末考有先解說題目（10題申論），再給大家兩分鐘討論，但遺憾的是有人認為這樣不公平而向系辦抗議，佳和於是用充滿委屈的語氣寄信給全班，說他以後不會再如此做。但佳和真的是非常認真的老師，之所以選擇這樣的上課及考試方式，無非是希望我們能真正深入思考憲政體制，幫老師QQ🥺，看threads就能知道佳和真的粉絲眾多。
# rating: 甜度：🍬🍬🍬🍬 涼度：🧊🧊
# :' metadata={'source': 'content.sorted.csv', 'row': 956, 'course_name': '憲法', 'teacher': '林佳和'}
# page_content='course name: 台灣電影與文學中的性別
# semester: N/A
# teacher: 陳佩甄
# reflection: 分數面來說，只要上課發言達三次，做好小組報告，翹課不要太誇張讓老師每次喊你都不到（因為老師會唱名幫忙找連絡不到的組員是否在場），分數不會差。課程面來說，上課會講一些性別主義的內容，老師的觀點切入觀點都非常有趣，讓人反思社會價值的合理性。課堂討論的氣氛很棒，同學發言的批判意識很高，推推有料人文通識。
# rating: 甜：5/5 涼：3/5 有料：5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 957, 'course_name': '台灣電影與文學中的性別', 'teacher': '陳佩甄'}
# page_content='course name: 近代臺灣歷史與人物
# semester: 112-1
# teacher: 鄭麗榕
# reflection: 老師會用簡報搭配PDF的補充教材上課，上課內容大部分都是高中課本沒有提到的那些台灣歷史，會以人物為主軸講述清朝以來的故事，老師很用心準備簡報和課程而且個性很溫柔可愛，上課氛圍很舒服，有興趣的人一定能在這堂課學到很多。還有這堂課是隨機分組，害怕找不到組員的同學也不用擔心！期中會有一次假日的校外參訪（我當時是大稻埕）並完成期中報告，每兩週一次的助教課都會點名，要與組員進行簡單的課堂討論並上台發表，也會有課後作業要寫，但大多都是一小時內就能完成。期末考是開書考，可以列印上課簡報和自己的筆記，題目都是上課的內容。整堂課最大的挑戰是小小說，老師會設定幾種時間點讓大家選（1935年台灣博覽會、1987年解嚴當天等等），最後一堂課會表揚寫得好的同學。我自己只寫了約1900字（但有取材自胡慧玲《臺灣之春》、張嘉祥《夜官巡場》、邱立崴《戰後五七八天》），最後也被老師和助教大力表揚＆稱讚🥺，非常喜歡老師和助教！結論是！我認為這堂課適合「對台灣史有興趣，但還不太了解」的人；對我這個已經熟讀許多台灣歷史相關書籍的人來說，上課內容就稍嫌平淡。不過我的學期成績沒有很好看的原因可能是，我好像有幾次作業遲交＆期末考沒寫好＆期末的作業直接沒交，老師抱歉我是廢物大學生😅。不過老師在113上沒有開這堂課，希望以後能再在課表上看到🥺。
# rating: 甜度：🍬🍬🍬 涼度：🧊🧊🧊
# :' metadata={'source': 'content.sorted.csv', 'row': 958, 'course_name': '近代臺灣歷史與人物', 'teacher': '鄭麗榕'}
# page_content='course name: 台語與台灣文化傳播
# semester: 112-2
# teacher: 周馥儀
# reflection: 這堂課有明顯的優點和缺點。優點是課程部分，老師主要是用簡報上課，並且會有講座，這學期是農村武裝青年主唱江育達、李江却台語文教基金會執行長陳豐惠、424刺蔣案槍手黃文雄。老師過去及現在都在用心推動台灣文化的傳承，教材內容也相當豐富，對台灣文化有興趣的人一定能有所收穫。但是，在授課部分，老師要求課堂全台語（所以我「不推薦」完全聽不懂台語的人來上這堂課），但老師的台語說得不太輾轉（liàn-tńg），也沒有學過任何一種台語羅馬字，對於教材中一些比較陌生的詞彙，老師也沒有事先準備，令人有點失望。作業部分難度都不高，會有兩次講座要寫心得，期中要選一項台語作品（音樂、影視、文學等）寫心得；基本上有寫出自己對這個議題的體會都會拿到高分。期末會進行分組報告，可以研究台語文化傳播現象或是發表台語創作。其實都是不難完成的作業，所以如果對台語和台灣文化有興趣的同學，整體來說我還是會推薦這堂課，能見到阿達和黃文雄前輩簡直物超所值。
# rating: 甜度：🍬🍬🍬 涼度：🧊🧊🧊
# :' metadata={'source': 'content.sorted.csv', 'row': 959, 'course_name': '台語與台灣文化傳播', 'teacher': '周馥儀'}
# page_content='course name: 統計學（二）
# semester: 112-2
# teacher: 周珮婷
# reflection: 上課方式跟上學期一樣，不去上課也有影片可以看，這學期多了程式作業，老師幾乎都把程式碼寫完了，不會很難。
# rating: 5/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 960, 'course_name': '統計學（二）', 'teacher': '周珮婷'}
# page_content='course name: 初級會計學（二）
# semester: 112-2
# teacher: 梁嘉紋
# reflection: 老師教的很好，除了課本以外還有講義可以輔助學習。助教超有耐心，哪裡不懂的都可以問她，回覆超快。
# rating: 5/5 & 3/5
# :' metadata={'source': 'content.sorted.csv', 'row': 961, 'course_name': '初級會計學（二）', 'teacher': '梁嘉紋'}
# page_content='course name: 武術中級
# semester: 112-2
# teacher: 張仲豪
# reflection: 一樣暖身做完才會點名，課程有點晚開始，需要自費彈力帶和彈力圈，若不想花錢要三思。
# rating: 5/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 962, 'course_name': '武術中級', 'teacher': '張仲豪'}
# page_content='course name: 商事法
# semester: 112-2
# teacher: 詹聰哲
# reflection: 老師上課生動有趣，期末考使用常態分佈給分，班上前20%就有90以上。
# rating: 5/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 963, 'course_name': '商事法', 'teacher': '詹聰哲'}
# page_content='course name: 管理學
# semester: 112-2
# teacher: 林介勝
# reflection: 這堂課重視小組活動，老師會記住同學的名字和長相，期末考與各種報告佔比重。
# rating: 3/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 964, 'course_name': '管理學', 'teacher': '林介勝'}
# page_content='course name: 投資學
# semester: 112-1
# teacher: 顏錫銘
# reflection: 老師很和藹，課程主要內容是選擇題，期末考題型為50題選擇題，報告分組自訂。
# rating: 3/5 & 3/5
# :' metadata={'source': 'content.sorted.csv', 'row': 965, 'course_name': '投資學', 'teacher': '顏錫銘'}
# page_content='course name: 民法概要
# semester: 112-1
# teacher: 詹聰哲
# reflection: 上課方式跟商事法差不多，這次沒有前20%。
# rating: 4/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 966, 'course_name': '民法概要', 'teacher': '詹聰哲'}
# page_content='course name: 選修英文：職場溝通
# semester: 112-1
# teacher: 崔正芳
# reflection: 上課使用老師自編課本，需到影印部買。若英文口語不好可能不太推薦這堂課，其他同學口語超流利自己進步較慢。
# rating: 3/5 & 2/5
# :' metadata={'source': 'content.sorted.csv', 'row': 967, 'course_name': '選修英文：職場溝通', 'teacher': '崔正芳'}
# page_content='course name: 統計學（一）
# semester: 111-2
# teacher: 周珮婷
# reflection: 上課方式跟上學期一樣，不去上課也有影片可以看，這學期多了程式作業，老師幾乎都把程式碼寫完了，不會很難。
# rating: 5/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 968, 'course_name': '統計學（一）', 'teacher': '周珮婷'}
# page_content='course name: 游泳中級
# semester: 111-1
# teacher: N/A
# reflection: 這門課比較像初級1.5，老師會從基礎的姿勢開始教，且進度較慢，但如果有不熟悉的動作，可以一對一詢問老師。課程的缺點是冬天游泳後淋浴間很擁擠，預先儲存的熱水不足，12月到1月時非常冷。
# rating: 3.5/5 & 3.5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 969, 'course_name': '游泳中級', 'teacher': 'N/A'}
# page_content='course name: 商用英文：口語溝通與談判技巧
# semester: 111-1
# teacher: 胡家榮
# reflection: 沒有紙筆考試，課程上會模擬商業談判並進行分組討論。期中需拍攝1分鐘英文自我介紹影片，期末會舉辦模擬會議，並提交修課心得。整體來說負擔輕，適合培養軟實力，氣氛輕鬆，老師友善，但有時會離題。
# rating: 3/5 & 3/5
# :' metadata={'source': 'content.sorted.csv', 'row': 970, 'course_name': '商用英文：口語溝通與談判技巧', 'teacher': '胡家榮'}
# page_content='course name: 會計師業務實戰研討
# semester: 111-2
# teacher: 柯志賢
# reflection: 課程由Deloitte事務所開設，課堂上會有不同講師或會計師演講，沒有考試，只有期中和期末兩篇心得報告。學習內容涵蓋會計實務，適合準備國考的學生。
# rating: 5/5 & 5/5
# :' metadata={'source': 'content.sorted.csv', 'row': 971, 'course_name': '會計師業務實戰研討', 'teacher': '柯志賢'}
# page_content='course name: 民法總則
# semester: 111-1
# teacher: 葉啟洲
# reflection: 總而言之啟洲一生推，課程沒有作業也不點名，期中期末各50%。老師會在一學期初教課速度較慢，但後期進度會很快，需要自行回家補充。老師出題很佛，有唸書就能拿不錯分數，期中期末考試題目不會刁鑽。
# rating: 4 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 972, 'course_name': '民法總則', 'teacher': '葉啟洲'}
# page_content='course name: 刑法（一）
# semester: 111-1
# teacher: 陳志輝
# reflection: 這是一門不涼的課，老師有大量預習影片及預習筆記，期中期末各20%。上課壓力大，預習筆記評分占40%，需花很多時間做筆記並寫作業。學期內卷壓力非常大，老師對優秀筆記的要求極高，且上課氣氛非常嚴肅。考試給分甜，但壓力很大。
# rating: ? & 1
# :' metadata={'source': 'content.sorted.csv', 'row': 973, 'course_name': '刑法（一）', 'teacher': '陳志輝'}
# page_content='course name: 基法導
# semester: 111-1
# teacher: 黃士軒
# reflection: 一個字讚，期末考100%，但有看過老師授課大綱就能輕鬆拿分。老師上課會隨機抽問問題，氣氛輕鬆，不會有太大壓力。加分機會很多，且老師會安排演講，報告心得可加分，非常適合學習基礎法學知識的學生。
# rating: 5 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 974, 'course_name': '基法導', 'teacher': '黃士軒'}
# page_content='course name: 大學英文（一）
# semester: 111-1
# teacher: 陳雅莉
# reflection: 老師上課氛圍輕鬆，關心學生，口語練習環境良好，課程沒有很多作業，期中期末考試適中。學英文程度較差的學生能獲得進步，課程適合學測後英文程度有所下降的學生。上課會有閱讀和口說任務，加分機會多。
# rating: 4.5 & 3.5-4
# :' metadata={'source': 'content.sorted.csv', 'row': 975, 'course_name': '大學英文（一）', 'teacher': '陳雅莉'}
# page_content='course name: ETP初會
# semester: 111-1
# teacher: 徐愛恩
# reflection: 會計學需要大量時間學習和重複練習，對於沒背景的學生壓力大。每週有預習筆記和小考，期中有三次考試和報告。老師會提供額外資源，但要求學習觀念精熟，考試注重基礎知識掌握。負擔大，需要有時間和英文能力較強的學生修課。
# rating: 1.5-2 & 1.5
# :' metadata={'source': 'content.sorted.csv', 'row': 976, 'course_name': 'ETP初會', 'teacher': '徐愛恩'}
# page_content='course name: 教育探索與自我學習
# semester: 111-1
# teacher: 顏敏仁
# reflection: 這門課主要講現代教育和地方創生，課程內容較為抽象。老師經常請來講者演講，作業不難，但期末報告和小組踏查需要花時間完成。學習的內容較為模糊，適合有興趣探索教育領域的學生。
# rating: 5 & 2.5-3
# :' metadata={'source': 'content.sorted.csv', 'row': 977, 'course_name': '教育探索與自我學習', 'teacher': '顏敏仁'}
# page_content='course name: 排球中級
# semester: 111-1
# teacher: 吳高讚
# reflection: 不建議對排球不熟悉的學生修，課程強調進階技巧，考試有壓力。老師有耐心，課程時間控制適中，適合有排球基礎的學生。考試要求基礎和進階技能，學習有一定難度，仍能適應但難度偏高。
# rating: 4.5 & 3
# :' metadata={'source': 'content.sorted.csv', 'row': 978, 'course_name': '排球中級', 'teacher': '吳高讚'}
# page_content='course name: 古典詩選讀
# semester: 111-1
# teacher: 許瑞哲
# reflection: 課程難度較高，老師非常親切耐心，雖然課程硬，但只要參與作業和期末報告就能過。期末考有選擇題但難度高，老師會在分數上有所調整，適合對古典詩感興趣並願意花時間研究的學生。
# rating: 2.5-3 & 2-2.5
# :' metadata={'source': 'content.sorted.csv', 'row': 979, 'course_name': '古典詩選讀', 'teacher': '許瑞哲'}
# page_content='course name: 語言與認知神經科學概論
# semester: 111-1
# teacher: 賴瑤瑛
# reflection: 這門課內容充實且極具啟發，討論神經語言學及心理語言學的概念，課堂上學到很多新知。期中期末報告及專案作業非常有意義，且能夠增強學習動機。期中是專案發想，期末則是完成專案並報告。老師安排了很多小組討論，有助於理解課程內容。這門課不僅學到理論，還能實際應用，強烈推薦。
# rating: 5 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 980, 'course_name': '語言與認知神經科學概論', 'teacher': '賴瑤瑛'}
# page_content='course name: 自我探索與心理健康
# semester: 111-1
# teacher: 楊啟正
# reflection: 課程內容關於自我覺察與心理健康，講師分享了很多實際應用的案例，學到如何促進心理健康與自我探索。期中報告和期末規劃的促進心理健康的旅遊報告不僅有趣且實用。這門課強調實踐與反思，對於有興趣提升自我認識與心理健康的人非常合適。
# rating: 4 & 4
# :' metadata={'source': 'content.sorted.csv', 'row': 981, 'course_name': '自我探索與心理健康', 'teacher': '楊啟正'}
# page_content='course name: 窺探科技中的語言應用
# semester: 111-1
# teacher: 張瑜芸
# reflection: 這門課結合了語言學與科技，運用Python學習情緒詞判斷和真偽訊息預測等有趣的應用。課程沒有期中考，只有期末專案，老師和助教非常有趣且熱情，會幫助學生逐步掌握程式語言，課堂氣氛輕鬆且具啟發性。這門課適合對語言學與科技有興趣的學生，並且能有效學到實務技能。
# rating: 5 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 982, 'course_name': '窺探科技中的語言應用', 'teacher': '張瑜芸'}
# page_content='course name: 生活中的生命科學
# semester: 111-1
# teacher: 陳紹寬
# reflection: 這門課對於不熟悉生命科學的學生來說，內容相對簡單，但期中考及期末報告對於有基礎的學生而言會有些挑戰。期中考是開放資料的問答題，期末報告題目不限，適合有興趣了解生命科學的學生。整體來說，這門課負擔不重，但若期望深入學習生命科學則可能會感到不足。
# rating: 3 & 3
# :' metadata={'source': 'content.sorted.csv', 'row': 983, 'course_name': '生活中的生命科學', 'teacher': '陳紹寬'}
# page_content='course name: 健康管理專題講座
# semester: 110-2
# teacher: 邱弘毅
# reflection: 這是一堂非常涼的通識課，每堂課都有不同的老師授課，且上課氣氛相對輕鬆，有些同學會點完名就離開。期中和期末都是開書考試，期中考會給好幾天時間寫，期末則限時三個小時，考試題目和上課ppt有關。適合想輕鬆拿學分、刷GPA的學生，考試不難，認真開書應該可以拿到不錯的分數。
# rating: 4 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 984, 'course_name': '健康管理專題講座', 'teacher': '邱弘毅'}
# page_content='course name: 商事法
# semester: 110-1
# teacher: 陳盈如
# reflection: 老師是一位非常漂亮的老師，講解法條非常詳細，會搭配案例來幫助理解。作業通常是小組形式，並且會有加分作業，期末考可以帶大抄。整體來說，這是一堂非常紮實且不太難的課程。
# rating: 4 & 3
# :' metadata={'source': 'content.sorted.csv', 'row': 985, 'course_name': '商事法', 'teacher': '陳盈如'}
# page_content='course name: 木球
# semester: 110-1
# teacher: 王思宜
# reflection: 每節課都會點名並進行熱身操，隨後大家會在場上打木球，課程相對比較輕鬆有趣。雖然木球桿有些重，會讓手酸，但老師會帶領一些有趣的小活動，使課程氛圍愉快。
# rating: 3.5 & 3
# :' metadata={'source': 'content.sorted.csv', 'row': 986, 'course_name': '木球', 'teacher': '王思宜'}
# page_content='course name: 法學素養
# semester: 110-2
# teacher: 陳靜慧
# reflection: 每節課帶不同議題，鼓勵同學發言討論，學期內有三次講座心得，期末作業需選擇題目撰寫3000字報告。整體課程強調思考與表達，但難度中等。
# rating: 3.5 & 2.5
# :' metadata={'source': 'content.sorted.csv', 'row': 987, 'course_name': '法學素養', 'teacher': '陳靜慧'}
# page_content='course name: 明清小說選讀
# semester: 110-2
# teacher: 林桂如
# reflection: 主要討論《三國演義》與《西遊記》，課程內容非常深入，需要大量筆記。整學期有小組報告和5000字的期末報告，期末考試考的是課堂筆記和小組報告的內容。這堂課學得很紮實，但壓力也大，對於有耐心的學生來說非常有成就感。
# rating: 2 & 1
# :' metadata={'source': 'content.sorted.csv', 'row': 988, 'course_name': '明清小說選讀', 'teacher': '林桂如'}
# page_content='course name: 國際財務管理
# semester: 110-2
# teacher: 張元晨
# reflection: 老師教學非常仔細，課堂上會安排小組介紹最新的財經情勢，並且會詳細解答學生的問題。期中期末考試不難，期末有小組報告，老師的給分也非常慷慨。課程內容紮實，推薦給對財務管理有興趣的學生。
# rating: 4 & 3
# :' metadata={'source': 'content.sorted.csv', 'row': 989, 'course_name': '國際財務管理', 'teacher': '張元晨'}
# page_content='course name: 音樂鑑賞（遠距通識）
# semester: 110-2
# teacher: N/A
# reflection: 課程由師大提供，需在商院遠距教室同步上課。期中考較簡單，課後需要聽三場音樂會並寫心得。這是一門輕鬆的課程，且提供了實際觀賞音樂會的機會，對音樂有興趣的學生會感到很有收穫。
# rating: 5 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 990, 'course_name': '音樂鑑賞（遠距通識）', 'teacher': 'N/A'}
# page_content='course name: 投資學
# semester: N/A
# teacher: 陳聖賢
# reflection: 這學期超級推薦的課程之一！老師進度雖然快，但非常有趣，能學到很多實務上的知識，特別是在如何跑出模型數據方面。老師很有耐心，回答問題很詳細。期中和期末考試是主要評分方式，考題難度適中，只要課堂上專心聽，課本習題有做，公式記熟就能順利應對。老師給分甜，推薦給有興趣的財務金融學生。
# rating: 5 & 4
# :' metadata={'source': 'content.sorted.csv', 'row': 991, 'course_name': '投資學', 'teacher': '陳聖賢'}
# page_content='course name: 貨幣理論與政策
# semester: N/A
# teacher: 張興華
# reflection: 這學期最喜歡的課之一！老師講解非常有趣，進度雖然慢，但很療癒。課程中涉及貨幣模型和Fed會議內容，對於有總經或貨銀背景的人來說會特別有趣。老師不僅聰明，而且非常有耐心，問問題時會細心解答。考試難度適中，只要認真上課，掌握模型和筆記就能輕鬆應對，老師給分也很寬鬆。推薦給喜歡貨幣理論的人。
# rating: 5 & 4
# :' metadata={'source': 'content.sorted.csv', 'row': 992, 'course_name': '貨幣理論與政策', 'teacher': '張興華'}
# page_content='course name: 初級會計學
# semester: N/A
# teacher: 郭泓卿
# reflection: 老師非常和藹，教學很詳細，課堂氛圍輕鬆。上課用板書，需自己記筆記，老師會提供練習題讓我們複習。考前一堂課會洩題，強烈建議參加。考試不難，基本題目，課堂專心聽，課本習題有做即可。期末會有三次考試和10%的額外加分。
# rating: 4.5 & 2
# :' metadata={'source': 'content.sorted.csv', 'row': 993, 'course_name': '初級會計學', 'teacher': '郭泓卿'}
# page_content='course name: 個體經濟學
# semester: N/A
# teacher: 黃柏鈞
# reflection: 老師講解簡單易懂，且會提供助教課進行進一步的輔導，助教整理的講義非常有用。考試大部分題目來自考古題，期末考會考上課筆記和小組報告內容。課程有趣且容易理解，老師授課節奏穩定，學生能輕鬆掌握知識。
# rating: 4.5 & 2
# :' metadata={'source': 'content.sorted.csv', 'row': 994, 'course_name': '個體經濟學', 'teacher': '黃柏鈞'}
# page_content='course name: 貨幣銀行學
# semester: N/A
# teacher: 林馨怡
# reflection: 老師很用心，課堂進度不快，且老師準備的講義和資料都很清楚。期中和期末考試會給題庫答案和考古題，考試有選擇題和問答題，考前提供充分的準備資料。平時成績由小白、作業和報告組成。
# rating: 3 & 1
# :' metadata={'source': 'content.sorted.csv', 'row': 995, 'course_name': '貨幣銀行學', 'teacher': '林馨怡'}
# page_content='course name: 財務管理
# semester: N/A
# teacher: 周冠男
# reflection: 老師非常清楚且條理分明地教學，授課內容實用，考試前會提供考古題，考試難度適中。學生需準備財務計算機，考試內容偏向計算公式及其推導。整體來說，老師給分偏高，期中期末考試有足夠的準備資料。
# rating: 4 & 1
# :' metadata={'source': 'content.sorted.csv', 'row': 996, 'course_name': '財務管理', 'teacher': '周冠男'}
# page_content='course name: 投資學
# semester: N/A
# teacher: 林靖庭（英文授課）
# reflection: 課程內容較淺，適合有基礎的學生，老師會講解一些基本的投資知識。課後作業和分組報告占學期成績，考試主要基於課堂內容。疫情後改為線上學習，部分學生認為課程不夠挑戰，老師會提前下課，對於有興趣學習的學生來說，這是一門輕鬆的課。
# rating: 5 & 4.5
# :' metadata={'source': 'content.sorted.csv', 'row': 997, 'course_name': '投資學', 'teacher': '林靖庭（英文授課）'}
# page_content='course name: 商事法
# semester: N/A
# teacher: 方嘉麟
# reflection: 課程以選擇題和互評組員作業為主，老師的授課方式輕鬆且開放，考試為開卷，學生可以使用手機和電腦。雖然考試內容較簡單，老師會提供選擇題的作答方式，但課程內容不夠深入，適合拿學分的學生選擇。
# rating: 5 & 5
# :' metadata={'source': 'content.sorted.csv', 'row': 998, 'course_name': '商事法', 'teacher': '方嘉麟'}

# %%
# ... (previous code) ...

# Ensure the model is downloaded and started
# !ollama start nomic-embed-text

#Check to see if it is downloaded
# !ollama list

# 利用 nomic-embed-text 模型，執行文本向量化
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

embeddings = OllamaEmbeddings(model="nomic-embed-text")
vector_db = Chroma.from_documents(documents=splits, embedding=embeddings)
# Out:
# Error: accepts 0 arg(s), received 1
# NAME                       ID              SIZE      MODIFIED
# nomic-embed-text:latest    0a109f422b47    274 MB    36 seconds ago
# gemma:7b                   a72c7f4d0a15    5.0 GB    4 minutes ago
# <ipython-input-35-7fdae672ddb0>:13: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %% [markdown]
# # 提問及抽取資料

# %%
# !ollama pull gemma:7b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling ef311de6af9d... 100% ▕▏ 5.0 GB
# pulling 097a36493f71... 100% ▕▏ 8.4 KB
# pulling 109037bec39c... 100% ▕▏  136 B
# pulling 65bb16cf5983... 100% ▕▏  109 B
# pulling 0c2a5137eb3c... 100% ▕▏  483 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ## 問題理解

# %%
rules = """
範例：
輸入：「民法總則的課程評價為何？」
回答：民法總則
輸入：「民總的課程評價怎麼樣呢？」
回答：民法總則
輸入：「程式設計的評價？」
回答：程式設計
輸入：尋找統計學相關課程評價
回答：統計學

根據上述範例回答下列敘述的課程名稱，切記勿直接回答輸入的問題，回答只會有課程名稱本身，不會有推理過程等額外資訊
"""

# %%
# 讓模型理解使用者問題，並抽取課名的關鍵字以供RAG查詢
def input_trans(question):
    # 製作提問用的提詞（Prompt）
    formatted_prompt = rules + question
    # 丟入 LLM，取得答案
    msg = llm.invoke(formatted_prompt)
    return msg

# %% [markdown]
# ## 根據抓取資料整理內容

# %%
# 讓模型依據"未經整理抓取資料"和"整理後結果"的配對示例，去整理各種從RAG資料庫裡提取的資訊
def info_arrange(course_info):
  course_prompt = formatted_course + "根據上面整理輸入輸出轉換的範例以老師為主提整理下方課程資訊，切忌回答勿直接使用範例輸入輸出，且只整理跟下列課程相關的資訊，用中文而非英文回答:" + course_info
  # 丟入 LLM，取得答案
  msg = llm.invoke(course_prompt)
  return msg

# %%
formatted_course = """
輸入範例1:
course name: 商事法
semester: 112-1
teacher: 王正偉
reflection: 課堂不點名，期中考試與期末報告為主要評分依據。對於法律零基礎的學生，教授會耐心指導並幫助學生通過課程。
rating: 甜度：4/5 涼度：4/5 分數：78
:

course name: 商事法總論與公司法＋公司法案例研習（二）
semester: 112-1
teacher: 周振鋒
reflection: 每週五上四個小時真的是要我命。不過老師常常安排專家學者在第四節講座，有稍微緩解不自覺靈魂出竅的狀況（對不擠我就是顆草莓）。考試可以帶大抄，這時候可以見識到大家word功力如何。建議考試前一週開始吃葉黃素，我當初沒吃，考完出來體感近視增加50度。曾經考慮要問老師可否帶放大鏡進考場。（當然如果你有讀熟才去考試、不用一直看大抄就不會遇到這種狀況）
rating: N/A
:

course name: 商事法
semester: 112-1
teacher: 鄭婷嫻
reflection: 老師教得很用心，認真聽課能學到不少法律知識。作業部分是小組合作，期末考試題目大多來自作業，有加分機會。
rating: 4/5 & 4/5
:

course name: 商事法
semester: N/A
teacher: 劉承愚
reflection: 上這堂課壓力有點大，要課前預習，但老師上課很精彩，會講到很多實務的東西，蠻有趣的。考試單選複選混在一起（就是你不知道這題是單選還是複選），但我也不知道我考試到底考幾分，分數有點玄
rating: 甜：🍭🍭🍭🍭🍭 涼：🧊🧊 分數：95-100
:

course name: 商事法
semester: 110-1
teacher: 陳盈如
reflection: 老師是一位非常漂亮的老師，講解法條非常詳細，會搭配案例來幫助理解。作業通常是小組形式，並且會有加分作業，期末考可以帶大抄。整體來說，這是一堂非常紮實且不太難的課程。
rating: 4 & 3

輸出範例1:
周振鋒
課程名稱：商事法總論與公司法＋公司法案例研習（二）

學期：112-1

課程特色：

每週安排4小時課程（含專家學者講座）。
考試可帶大抄，需製作詳細筆記。
學生評價：

長課時挑戰較大，適合有耐心與充分準備的學生。
整體課程重心放在實務案例與考試應對技巧。
鄭婷嫻
課程名稱：商事法

學期：112-1

課程特色：

作業以小組合作為主，期末考試題目多來自作業。
提供加分機會，期末考試強調知識運用與應用。
學生評價：

老師教學認真，適合用心學習的學生。
分數整體甜度與涼度相當高（4/5）。
劉承愚
課程名稱：商事法

學期：N/A

課程特色：

課前需要預習，上課內容精彩，重點放在實務應用。
考試包含單選與複選混合題型，需仔細準備。
學生評價：

老師講課有趣，但壓力偏大。
成績高甜（甜度🍭🍭🍭🍭🍭，涼度🧊🧊，分數約95-100分）。
陳盈如
課程名稱：商事法

學期：110-1

課程特色：

老師講解法條詳細，搭配案例幫助理解。
作業與期末考試設計較友善，期末考試可帶大抄。
學生評價：

老師非常漂亮，課程紮實且不難。
整體甜度與涼度適中（4/5 & 3/5），適合希望穩紮穩打學習法律基礎的學生。

輸入範例2:
course name: 中國大陸概論
semester: 110-2
teacher: 王信賢
reflection: 評分方式：50%課堂表現（主要是出席、小組報告的組內與組間互評）、50%期末考 分數：95-99 心得：這堂也是我超喜歡的通識課之一，老師上課非常有料，對中國的各方面都會有所介紹，同時也會分享一些老師去做田野的趣事！最後課程也會有兵推～整體負擔也不會太大，每次上正課都很希望老師可以繼續講下去，在期末考前主要只需要準備小組的口頭報告即可，助教也會事前和大家約時間給予大家建議，期末考的部分老師上課也會提示，有好好上課應該不會太難，不過老師不會提供PPT，只會提供講綱給大家做筆記
rating: 甜度：4.5/5 涼度：3/5
:

course name: 中國大陸概論
semester: 111-1
teacher: 林義鈞
reflection: 不開放加簽！是一門初選排一還不一定會上的搶手課程。 這個學期要寫五篇預習心得、三篇加分用的觀影心得和三篇加分用的講座心得，以核通而言這個作業量應該還算適中。第二週就會分組，討論課（18:00-19:00）和期末報告都會需要你的組員。 課程內容會介紹政治、社會、經濟、外交。前兩個小時是教授講述內容，課前會把PPT上傳到Moodle上給大家參看，有需要的人可以下載下來做筆記。教授為人相當親切、樂於稱讚學生，也會冷不防逗大家笑。我認為修過這堂課之後，對於兩岸的情勢有更全面性的理解，課後在聽別人討論相關議題的時候也會比較快融入；比較可惜的是因為時間因素，有些主題沒辦法討論太久。學期中的三次演講邀請了學界的專家來分享研究成果和所見所聞，我覺得很值得一聽。 最後一個小時是討論課，學期初將十幾組分成兩個班，各自讓兩位助教帶領討論對岸的時事議題。 我當時對這個領域很有興趣，所以上得很開心xDDD 但無論如何都是一堂值得推推的好課
rating: 甜度：4 涼度：3.8
:

course name: 中國大陸概論
semester: 1121
teacher: 林義鈞
reflection: 上課內容很豐富，基本上政治經濟社會都有講到，老師上課也很認真，可以學到很多東西，助教課氛圍也還算輕鬆，另外有指定教科書。作業有數次心得跟小組書面報告。心得就是閱讀完指定教科書特定章節的心得，書面報告也不會太難做。有期中期末，但期末可以帶參考資料(至少當時可以)。然後會有看電影跟演講，有寫心得可以加分。
rating: 甜度：5/5 涼度：4.5/5 分數：98
:

course name: 中國大陸概論
semester: N/A
teacher: 唐玉禮
reflection: 好像不太加簽。又是一堂大家都在划手機看電腦做自己事的課，老師其實人滿好的很親切，上課內容偏無聊，每個禮拜看老師給的報導寫600字心得，我自己覺得負擔不太重，期末小組上台報告外加個人報告(網路繳交即可)。偶爾點名，不雷但也不是大家會狂推的課，可以選。
rating: 甜度：4/5 涼度：3/5
:

course name: 中國大陸概論
semester: 107
teacher: 林義鈞
reflection: 沒有想像中甜，不知道有沒有故意壓低成績，但期中真的佛到爆，完全不用準備就可以100，期末申論題。助教人也很好，很認真在帶討論。
rating: 甜度：4/5 涼度：3/5
:

course name: 中國大陸概論
semester: 110-1
teacher: 林義鈞
reflection: 上課方式多元，包括授課、講師演講與電影欣賞。期中期末考難度適中，討論課與專題報告負擔適中，是負擔較輕的核心通識課，推薦對中國議題有興趣的同學選修。
rating: 甜：4/5 涼：4.5/5

輸出範例2:
**王信賢**

課程名稱：中國大陸概論

學期：110-2

課程特色：講課富有內容，教授有深度研究中國各方面，並分享個人經驗。期末考僅需口頭報告。

**林義鈞**

課程名稱：中國大陸概論

學期：111-1、112-1、107、110-1

課程特色：教授熱情洋溢，講課認真，並會引導討論。作業量適中，並有定期演講和電影欣賞。

**唐玉禮**

課程名稱：中國大陸概論

學期：N/A

課程特色：教授人滿有禮，但課程內容平淡。作業量輕微，但定期點名。

"""

# %% [markdown]
# ## RAG資料抓取及回答整體流程

# %%
# 定義向量資料庫抽取物件
retriever = vector_db.as_retriever(search_kwargs={"k": 200 })

# 根據與使用者問題的相似度，抽取相關資料(測試用，用於檢查抽取資料及模型理解問題的效果)
def get_rag_docs_test(question):
    # 依照與問題的相似度，抽取相關文本
    retrieved_docs = retriever.invoke(question)
    refined_docs = []
    # 將所有相關文本，以空行 \n\n 黏成一個大字串
    class_name = input_trans(question)
    print(class_name)
    for doc in retrieved_docs:
      if class_name in doc.metadata["course_name"]:  # 根據具體需求進行進一步篩選
        refined_docs.append(doc)
    relavent_contents = "\n\n".join(doc.page_content for doc in refined_docs)
    print("參考資料：" + "\n\n")
    output = info_arrange(relavent_contents)
    return output
    # return llm_ask(question, relavent_contents)

# %%
# 定義向量資料庫抽取物件
retriever = vector_db.as_retriever(search_kwargs={"k": 200 })

# 根據與使用者問題的相似度，抽取相關資料
def get_rag_docs(question):
    # 依照與問題的相似度，抽取相關文本
    retrieved_docs = retriever.invoke(question)
    refined_docs = []
    # 將所有相關文本，以空行 \n\n 黏成一個大字串
    class_name = input_trans(question)
    for doc in retrieved_docs:
      if class_name in doc.metadata["course_name"]:  # 根據具體需求進行進一步篩選
        refined_docs.append(doc)
    relavent_contents = "\n\n".join(doc.page_content for doc in refined_docs)
    # 將問題 + RAG 相關文本，一口氣丟入 LLM，取得答案
    output = info_arrange(relavent_contents)
    return output
    # return llm_ask(question, relavent_contents)

# %%
# 定義一個能丟入「使用者問題」與「RAG 抽取之相關文本」，用來詢問 LLM 的函數
def llm_ask(question, rag_contents):
    # 製作提問用的提詞（Prompt）
    formatted_prompt = f"Question: {question}\n\nContext: {rag_contents}"
    # 丟入 LLM，取得答案
    msg = llm.invoke(formatted_prompt)
    return msg

# %% [markdown]
# ## 實際問答範例

# %%
print(get_rag_docs("告訴我社會學相關課程的評價"))
# Out:
# **陳宗文**
#
# 課程名稱：社會學動動腦
#
# 學期：112-2
#
# 課程特色：教授有深度研究社會學的觀點，並分享個人經驗。期末展演是一組做一個海報。
#
# **姜以琳**
#
# 課程名稱：社會學
#
# 學期：N/A
#
# 課程特色：適合入門，教授很可愛很有趣。考試有英文文獻。
#
# **關秉寅**
#
# 課程名稱：社會學動動腦
#
# 學期：1071
#
# 課程特色：上課涼，給分極甜，但有學習價值。

# %%
print(get_rag_docs_test("告訴我民法相關課程的評價"))
# Out:
# 民法總則
# 參考資料：
#
#
# **民法總則課程評量表**
#
# | 教師 | 甜度 | 涼度 | 分數 | 推薦指數 |
# |---|---|---|---|---|
# | 吳瑾瑜 | 4/5 | 4/5 | 95 | 🍎🍎 |
# | 牛曰正 | 4/5 | 3/5 | 80 | 🍎 |
# | 周伯峰 | N/A | N/A | N/A | N/A |
# | 牛曰正 | 4/5 | 3/5 | 90-94 | 🍎🍎 |
# | 吳瑾瑜 | 4/5 | 3/5 | 90-94 | 🍎🍎 |
#
# **評量標準：**
#
# * **甜度：**課程教學風格、教材選定、教學互動等。
# * **涼度：**課程內容的複雜程度、教學速度和質量。
#
# **推薦指數：**
#
# * **🍎🍎：**非常推薦。
# * **🍎：**推薦。
#
# **備註：**
#
# * 教師的教學風格和教學品質會影響課程的甜度和涼度。
# * 建議學生根據自己的學習需求和興趣選擇課程。

# %% [markdown]
# # 串接line bot (與個人綁定，無法在colab上運行)

# %% [markdown]
# ## 安裝 ngrok 網頁伺服器相關套件
#
# * 細節可以參考： https://pyngrok.readthedocs.io/en/latest/integrations.html#google-colaboratory

# %%
# 安裝 pyngrok。一款專為 Python 打造的 ngrok 網頁伺服器。
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)

# %%
# 取得 ngrok 登入金鑰（Authtoken）並加入 Linux 系統中
# 登入 ngrok 主頁面： https://ngrok.com/
# 點擊左側欄 "Getting Started" > "Your Authtoken"
# 將畫面中央標示為 "Command Line" 的命令，拷貝貼上
# 金鑰（Authtoken）每人不同，請勿照抄別人的金鑰。
# 個人金鑰不會改變，請妥善保管。
# !ngrok config add-authtoken 2pp658abCbmLJ9kpV49OOI9ERHV_4aqEEJpMmYD8hR73Zn17e
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# ## 攔截 LINE 訊息
#
# * 細節請看這個網站： https://github.com/line/line-bot-sdk-python

# %%
# 安裝 Line Bot SDK
# !pip install line-bot-sdk
# Out:
# Requirement already satisfied: line-bot-sdk in /usr/local/lib/python3.10/dist-packages (3.14.2)
# Requirement already satisfied: requests<3,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (2.32.3)
# Requirement already satisfied: urllib3<3,>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (2.2.3)
# Requirement already satisfied: aiohttp>=3.10.9 in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (3.11.10)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (1.0.0)
# Requirement already satisfied: pydantic<3,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (2.10.3)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (3.1.15)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (2.8.2)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from line-bot-sdk) (1.2.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.10.9->line-bot-sdk) (1.18.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.0.3->line-bot-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.0.3->line-bot-sdk) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=2.0.3->line-bot-sdk) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->line-bot-sdk) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.3->line-bot-sdk) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.3->line-bot-sdk) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.3->line-bot-sdk) (2024.12.14)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->line-bot-sdk) (1.17.0)

# %%
# 攔截 LINE 訊息主程式，可由 LINE Bot SDK 網站拷貝得到

# 引入 Flask 網頁伺服器存取套件
from flask import Flask, request, abort

# 引入 Line Bot SDK 相關套件
from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent
)

# 引入 pyngrok 相關套件
import os
import threading
from pyngrok import ngrok



# 產生一個 Flask 物件，連上 Web 伺服器
app = Flask(__name__)

# 啟動 ngrok
# 將 ngrok 連往 Flask 預設埠號 5000
port = "5000"
# 取得 ngrok 公共 URL
public_url = ngrok.connect(port).public_url
# 印出 ngrok 公共 URL，並告知連往本地端埠號 5000
print(f" * ngrok tunnel '{public_url}' -> 'http://127.0.0.1:{port}'")
# 將本服務的網址，由 localhost，轉為公共的 URL
app.config["BASE_URL"] = public_url

# Channel Acess Token 類似登入帳號，Channel Secret 類似登入密碼
# 兩者請至 LINE Developer 網站，相應 Channel 內取得
configuration = Configuration(access_token='qwcjeaCFzIGLARixUMmzln3sxZd/Q3K7rO+oJua8BjGct6/qpqAoHfc+l0AYdYyJzDm/Q+4wTD8Tf7qhWl+RnEJU4X1EQnM/Zbndi2JIaEu4bb1laKcZRYAtNhyZrEcwDMcGYtcmY27ymOHxOkeougdB04t89/1O/w1cDnyilFU=')
handler = WebhookHandler('ab6299fe3bbe6e44cdeedd0db91c4647')

# 測試 ngrok 伺服器是否正常運作之函數
@app.route("/")
def index():
    return "Hello from ngrok!"

# 網頁封包處理函數，不要更動
@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'

# 網頁訊息處理函數，可以客製化
@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)

        # 使用 RAG 處理用戶輸入的訊息
        user_message = event.message.text
        try:
            reply_message = get_rag_docs(user_message)  # 使用 RAG 獲取回覆
        except Exception as e:
            # 若 RAG 出現錯誤，回傳預設訊息
            reply_message = "抱歉，我無法處理您的問題。"

        # 回覆用戶訊息
        line_bot_api.reply_message_with_http_info(
            ReplyMessageRequest(
                reply_token=event.reply_token,
                messages=[TextMessage(text=reply_message)]
            )
        )

if __name__ == "__main__":
    # 以另一條執行緒將 Flask 啟動於背景，免得阻塞 Colab 使之無法操作
    threading.Thread(target=app.run, kwargs={"use_reloader": False}).start()
# Out:
#  * ngrok tunnel 'https://3f80-34-142-133-41.ngrok-free.app' -> 'http://127.0.0.1:5000'
#  * Serving Flask app '__main__'
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#   File "/usr/local/lib/python3.10/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#   File "/usr/local/lib/python3.10/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# This typically means that you attempted to use functionality that needed
# an active HTTP request. Consult the documentation on testing for
# information about how to avoid this problem.
#  * Debug mode: off
